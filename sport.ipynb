# %%
import mysql.connector

# %%
data=[
    
    
        {
          "rank": 272,
          "movement": 3,
          "points": 254,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:686709",
            "name": "Simakin, Ilia",
            "country": "Neutral",
            "abbreviation": "SIM"
          }
        },
        {
          "rank": 273,
          "movement": 5,
          "points": 252,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:82133",
            "name": "Dellien, Murkel",
            "country": "Bolivia",
            "country_code": "BOL",
            "abbreviation": "DEV"
          }
        },
        {
          "rank": 274,
          "movement": 5,
          "points": 252,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:614090",
            "name": "Pieczonka, Filip",
            "country": "Poland",
            "country_code": "POL",
            "abbreviation": "PIE"
          }
        },
        {
          "rank": 275,
          "movement": 6,
          "points": 251,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:49548",
            "name": "Manafov, Vladyslav",
            "country": "Ukraine",
            "country_code": "UKR",
            "abbreviation": "MAN"
          }
        },
        {
          "rank": 276,
          "movement": 6,
          "points": 251,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:398360",
            "name": "Urrea, Andres",
            "country": "Colombia",
            "country_code": "COL",
            "abbreviation": "URR"
          }
        },
        {
          "rank": 277,
          "movement": -28,
          "points": 251,
          "competitions_played": 27,
          "competitor": {
            "id": "sr:competitor:126402",
            "name": "Denolly, Corentin",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "DEN"
          }
        },
        {
          "rank": 278,
          "movement": 5,
          "points": 250,
          "competitions_played": 3,
          "competitor": {
            "id": "sr:competitor:44553",
            "name": "Herbert, Pierre-Hugues",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "HER"
          }
        },
        {
          "rank": 279,
          "movement": 20,
          "points": 249,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:79227",
            "name": "Sinclair, Colin",
            "country": "Northern Mariana Islands",
            "country_code": "MNP",
            "abbreviation": "SIN"
          }
        },
        {
          "rank": 280,
          "movement": 4,
          "points": 249,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:93597",
            "name": "Pellegrino, Andrea",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "PEL"
          }
        },
        {
          "rank": 281,
          "movement": 4,
          "points": 249,
          "competitions_played": 30,
          "competitor": {
            "id": "sr:competitor:645442",
            "name": "Genov, Anthony",
            "country": "Bulgaria",
            "country_code": "BGR",
            "abbreviation": "GEN"
          }
        },
        {
          "rank": 282,
          "movement": 4,
          "points": 248,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:180104",
            "name": "Reymond, Arthur",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "REY"
          }
        },
        {
          "rank": 283,
          "movement": -13,
          "points": 242,
          "competitions_played": 9,
          "competitor": {
            "id": "sr:competitor:145122",
            "name": "Martineau, Matteo",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "MAR"
          }
        },
        {
          "rank": 284,
          "movement": 6,
          "points": 242,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:130436",
            "name": "Habib, Hady",
            "country": "Lebanon",
            "country_code": "LBN",
            "abbreviation": "HAB"
          }
        },
        {
          "rank": 285,
          "movement": 8,
          "points": 242,
          "competitions_played": 27,
          "competitor": {
            "id": "sr:competitor:731833",
            "name": "Kielan, Szymon",
            "country": "Poland",
            "country_code": "POL",
            "abbreviation": "KIE"
          }
        },
        {
          "rank": 286,
          "movement": 5,
          "points": 241,
          "competitions_played": 8,
          "competitor": {
            "id": "sr:competitor:94485",
            "name": "Bonzi, Benjamin",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "BON"
          }
        },
        {
          "rank": 287,
          "movement": -50,
          "points": 241,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:49663",
            "name": "Escoffier, Antoine",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "ESC"
          }
        },
        {
          "rank": 288,
          "movement": 4,
          "points": 241,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:214824",
            "name": "Aguilar, Juan Carlos",
            "country": "Canada",
            "country_code": "CAN",
            "abbreviation": "AGU"
          }
        },
        {
          "rank": 289,
          "movement": 6,
          "points": 240,
          "competitions_played": 7,
          "competitor": {
            "id": "sr:competitor:104847",
            "name": "Sonego, Lorenzo",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "SON"
          }
        },
        {
          "rank": 290,
          "movement": 6,
          "points": 240,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:774476",
            "name": "Debru, Gabriel",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "DEB"
          }
        },
        {
          "rank": 291,
          "movement": -11,
          "points": 240,
          "competitions_played": 27,
          "competitor": {
            "id": "sr:competitor:196672",
            "name": "Davis, James",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "DAV"
          }
        },
        {
          "rank": 292,
          "movement": -29,
          "points": 239,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:161220",
            "name": "Pavel, Bogdan",
            "country": "Romania",
            "country_code": "ROU",
            "abbreviation": "PAV"
          }
        },
        {
          "rank": 293,
          "movement": 4,
          "points": 238,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:759900",
            "name": "Lanik, Tomas",
            "country": "Slovakia",
            "country_code": "SVK",
            "abbreviation": "LAN"
          }
        },
        {
          "rank": 294,
          "movement": 25,
          "points": 237,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:163540",
            "name": "Hermans, Mats",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "HER"
          }
        },
        {
          "rank": 295,
          "movement": 3,
          "points": 236,
          "competitions_played": 30,
          "competitor": {
            "id": "sr:competitor:217192",
            "name": "Ouakaa, Aziz",
            "country": "Tunisia",
            "country_code": "TUN",
            "abbreviation": "OUA"
          }
        },
        {
          "rank": 296,
          "movement": 15,
          "points": 234,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:251091",
            "name": "Noguchi, Rio",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "NOG"
          }
        },
        {
          "rank": 297,
          "movement": 21,
          "points": 232,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:132558",
            "name": "Kolar, Zdenek",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "KOL"
          }
        },
        {
          "rank": 298,
          "movement": 2,
          "points": 232,
          "competitions_played": 27,
          "competitor": {
            "id": "sr:competitor:154570",
            "name": "Orlov, Vladyslav",
            "country": "Ukraine",
            "country_code": "UKR",
            "abbreviation": "ORL"
          }
        },
        {
          "rank": 299,
          "movement": 2,
          "points": 232,
          "competitions_played": 28,
          "competitor": {
            "id": "sr:competitor:452787",
            "name": "Kumar, Pranav",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "KUM"
          }
        },
        {
          "rank": 300,
          "movement": -33,
          "points": 231,
          "competitions_played": 40,
          "competitor": {
            "id": "sr:competitor:51304",
            "name": "Stevenson, Kelsey",
            "country": "Canada",
            "country_code": "CAN",
            "abbreviation": "STE"
          }
        },
        {
          "rank": 301,
          "movement": -65,
          "points": 228,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:55787",
            "name": "Olivo, Renzo",
            "country": "Argentina",
            "country_code": "ARG",
            "abbreviation": "OLI"
          }
        },
        {
          "rank": 302,
          "movement": -50,
          "points": 227,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:17359",
            "name": "Oswald, Philipp",
            "country": "Austria",
            "country_code": "AUT",
            "abbreviation": "OSW"
          }
        },
        {
          "rank": 303,
          "movement": -1,
          "points": 225,
          "competitions_played": 7,
          "competitor": {
            "id": "sr:competitor:15931",
            "name": "Brown, Dustin",
            "country": "Jamaica",
            "country_code": "JAM",
            "abbreviation": "BRO"
          }
        },
        {
          "rank": 304,
          "movement": -1,
          "points": 225,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:51141",
            "name": "Carballes Baena, Roberto",
            "country": "Spain",
            "country_code": "ESP",
            "abbreviation": "CAR"
          }
        },
        {
          "rank": 305,
          "movement": -1,
          "points": 222,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:645452",
            "name": "Nesterov, Pyotr",
            "country": "Bulgaria",
            "country_code": "BGR",
            "abbreviation": "NES"
          }
        },
        {
          "rank": 306,
          "movement": -1,
          "points": 222,
          "competitions_played": 25,
          "competitor": {
            "id": "sr:competitor:103625",
            "name": "Geerts, Michael",
            "country": "Belgium",
            "country_code": "BEL",
            "abbreviation": "GEE"
          }
        },
        {
          "rank": 307,
          "movement": -1,
          "points": 221,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:170964",
            "name": "Bittoun Kouzmine, Constantin",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "BIT"
          }
        },
        {
          "rank": 308,
          "movement": -1,
          "points": 218,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:60614",
            "name": "Poljak, David",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "POL"
          }
        },
        {
          "rank": 309,
          "movement": 0,
          "points": 217,
          "competitions_played": 9,
          "competitor": {
            "id": "sr:competitor:226124",
            "name": "Holmgren, August",
            "country": "Denmark",
            "country_code": "DNK",
            "abbreviation": "HOL"
          }
        },
        {
          "rank": 310,
          "movement": 0,
          "points": 216,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:682911",
            "name": "Faria, Jaime",
            "country": "Portugal",
            "country_code": "PRT",
            "abbreviation": "FAR"
          }
        },
        {
          "rank": 311,
          "movement": 1,
          "points": 213,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:240264",
            "name": "Reis Da Silva, Joao Lucas",
            "country": "Brazil",
            "country_code": "BRA",
            "abbreviation": "REI"
          }
        },
        {
          "rank": 312,
          "movement": 1,
          "points": 212,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:505542",
            "name": "Grevelius, Erik",
            "country": "Sweden",
            "country_code": "SWE",
            "abbreviation": "GRE"
          }
        },
        {
          "rank": 313,
          "movement": 2,
          "points": 211,
          "competitions_played": 9,
          "competitor": {
            "id": "sr:competitor:113905",
            "name": "Moreno de Alboran, Nicolas",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "MAN"
          }
        },
        {
          "rank": 314,
          "movement": -6,
          "points": 210,
          "competitions_played": 24,
          "competitor": {
            "id": "sr:competitor:121248",
            "name": "Roveri Sidney, Gabriel",
            "country": "Brazil",
            "country_code": "BRA",
            "abbreviation": "ROV"
          }
        },
        {
          "rank": 315,
          "movement": 1,
          "points": 209,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:437794",
            "name": "Heinonen, Adam",
            "country": "Sweden",
            "country_code": "SWE",
            "abbreviation": "HEI"
          }
        },
        {
          "rank": 316,
          "movement": 57,
          "points": 209,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:973963",
            "name": "Watt, James",
            "country": "New Zealand",
            "country_code": "NZL",
            "abbreviation": "WAT"
          }
        },
        {
          "rank": 317,
          "movement": 0,
          "points": 208,
          "competitions_played": 5,
          "competitor": {
            "id": "sr:competitor:603098",
            "name": "Fery, Arthur",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "FER"
          }
        },
        {
          "rank": 318,
          "movement": 2,
          "points": 205,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:312436",
            "name": "Hudd, Emile",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "HUD"
          }
        },
        {
          "rank": 319,
          "movement": 2,
          "points": 203,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:50360",
            "name": "Margaroli, Luca",
            "country": "Switzerland",
            "country_code": "CHE",
            "abbreviation": "MAR"
          }
        },
        {
          "rank": 320,
          "movement": 2,
          "points": 201,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:52276",
            "name": "Krueger, Mitchell",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "KRU"
          }
        },
        {
          "rank": 321,
          "movement": 2,
          "points": 200,
          "competitions_played": 4,
          "competitor": {
            "id": "sr:competitor:67154",
            "name": "Barrere, Gregoire",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "BAR"
          }
        },
        {
          "rank": 322,
          "movement": 2,
          "points": 200,
          "competitions_played": 8,
          "competitor": {
            "id": "sr:competitor:124656",
            "name": "Vukic, Aleksandar",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "VUK"
          }
        },
        {
          "rank": 323,
          "movement": 68,
          "points": 200,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:287543",
            "name": "Hulme, Matt",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "HUL"
          }
        },
        {
          "rank": 324,
          "movement": -10,
          "points": 200,
          "competitions_played": 32,
          "competitor": {
            "id": "sr:competitor:767058",
            "name": "Lobanov, Aleksandr",
            "country": "Neutral",
            "abbreviation": "LOB"
          }
        },
        {
          "rank": 325,
          "movement": 0,
          "points": 199,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:739643",
            "name": "Loof, Thijmen",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "LOO"
          }
        },
        {
          "rank": 326,
          "movement": -39,
          "points": 197,
          "competitions_played": 30,
          "competitor": {
            "id": "sr:competitor:154490",
            "name": "Pearson, Kody",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "PEA"
          }
        },
        {
          "rank": 327,
          "movement": -1,
          "points": 196,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:686911",
            "name": "Poljicak, Mili",
            "country": "Croatia",
            "country_code": "HRV",
            "abbreviation": "POL"
          }
        },
        {
          "rank": 328,
          "movement": 8,
          "points": 196,
          "competitions_played": 27,
          "competitor": {
            "id": "sr:competitor:381022",
            "name": "Wendelken, Harry",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "WEN"
          }
        },
        {
          "rank": 329,
          "movement": -2,
          "points": 196,
          "competitions_played": 30,
          "competitor": {
            "id": "sr:competitor:202735",
            "name": "Carou, Ignacio",
            "country": "Uruguay",
            "country_code": "URY",
            "abbreviation": "CAR"
          }
        },
        {
          "rank": 330,
          "movement": -2,
          "points": 194,
          "competitions_played": 7,
          "competitor": {
            "id": "sr:competitor:80665",
            "name": "Polmans, Marc",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "POL"
          }
        },
        {
          "rank": 331,
          "movement": -2,
          "points": 194,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:655845",
            "name": "Quinn, Ethan",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "QUI"
          }
        },
        {
          "rank": 332,
          "movement": -2,
          "points": 194,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:17046",
            "name": "Statham, Rubin",
            "country": "New Zealand",
            "country_code": "NZL",
            "abbreviation": "STA"
          }
        },
        {
          "rank": 333,
          "movement": -2,
          "points": 193,
          "competitions_played": 32,
          "competitor": {
            "id": "sr:competitor:458575",
            "name": "Agostini, Simone",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "AGO"
          }
        },
        {
          "rank": 334,
          "movement": -2,
          "points": 193,
          "competitions_played": 35,
          "competitor": {
            "id": "sr:competitor:124934",
            "name": "Lomakin, Grigoriy",
            "country": "Kazakhstan",
            "country_code": "KAZ",
            "abbreviation": "LOM"
          }
        },
        {
          "rank": 335,
          "movement": -2,
          "points": 192,
          "competitions_played": 37,
          "competitor": {
            "id": "sr:competitor:223788",
            "name": "Stepanov, Roy",
            "country": "Israel",
            "country_code": "ISR",
            "abbreviation": "STE"
          }
        },
        {
          "rank": 336,
          "movement": -2,
          "points": 191,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:205767",
            "name": "Cretu, Cezar (2001)",
            "country": "Romania",
            "country_code": "ROU",
            "abbreviation": "CRE"
          }
        },
        {
          "rank": 337,
          "movement": -2,
          "points": 190,
          "competitions_played": 8,
          "competitor": {
            "id": "sr:competitor:387066",
            "name": "Forejtek, Jonas",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "FOR"
          }
        },
        {
          "rank": 338,
          "movement": 5,
          "points": 190,
          "competitions_played": 27,
          "competitor": {
            "id": "sr:competitor:407791",
            "name": "Mackinlay, James",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "MAC"
          }
        },
        {
          "rank": 339,
          "movement": -2,
          "points": 185,
          "competitions_played": 24,
          "competitor": {
            "id": "sr:competitor:452691",
            "name": "Araujo, Pedro",
            "country": "Portugal",
            "country_code": "PRT",
            "abbreviation": "ARA"
          }
        },
        {
          "rank": 340,
          "movement": -1,
          "points": 183,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:111609",
            "name": "Barroso Campos, Alberto",
            "country": "Spain",
            "country_code": "ESP",
            "abbreviation": "BAR"
          }
        },
        {
          "rank": 341,
          "movement": 24,
          "points": 183,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:95939",
            "name": "Whitehouse, Mark",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "WHI"
          }
        },
        {
          "rank": 342,
          "movement": -2,
          "points": 183,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:437734",
            "name": "Shin, Woobin",
            "country": "Republic of Korea",
            "country_code": "KOR",
            "abbreviation": "SHI"
          }
        },
        {
          "rank": 343,
          "movement": -2,
          "points": 183,
          "competitions_played": 29,
          "competitor": {
            "id": "sr:competitor:229024",
            "name": "Zahraj, Patrick",
            "country": "Germany",
            "country_code": "DEU",
            "abbreviation": "ZAH"
          }
        },
        {
          "rank": 344,
          "movement": -2,
          "points": 182,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:118166",
            "name": "Bakshi, Aleksandre",
            "country": "Georgia",
            "country_code": "GEO",
            "abbreviation": "BAK"
          }
        },
        {
          "rank": 345,
          "movement": 21,
          "points": 181,
          "competitions_played": 27,
          "competitor": {
            "id": "sr:competitor:220590",
            "name": "Huang, Tsung-Hao",
            "country": "Chinese Taipei",
            "country_code": "TPE",
            "abbreviation": "HUA"
          }
        },
        {
          "rank": 346,
          "movement": -2,
          "points": 180,
          "competitions_played": 2,
          "competitor": {
            "id": "sr:competitor:57703",
            "name": "Pouille, Lucas",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "POU"
          }
        },
        {
          "rank": 347,
          "movement": -2,
          "points": 180,
          "competitions_played": 2,
          "competitor": {
            "id": "sr:competitor:429603",
            "name": "Rune, Holger",
            "country": "Denmark",
            "country_code": "DNK",
            "abbreviation": "RUN"
          }
        },
        {
          "rank": 348,
          "movement": -2,
          "points": 180,
          "competitions_played": 3,
          "competitor": {
            "id": "sr:competitor:163504",
            "name": "Medvedev, Daniil",
            "country": "Neutral",
            "abbreviation": "MED"
          }
        },
        {
          "rank": 349,
          "movement": -2,
          "points": 180,
          "competitions_played": 4,
          "competitor": {
            "id": "sr:competitor:225050",
            "name": "Sinner, Jannik",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "SIN"
          }
        },
        {
          "rank": 350,
          "movement": -2,
          "points": 180,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:193912",
            "name": "Dev, S D Prajwal",
            "country": "India",
            "country_code": "IND",
            "abbreviation": "DEV"
          }
        },
        {
          "rank": 351,
          "movement": -2,
          "points": 178,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:286367",
            "name": "Krutykh, Oleksii",
            "country": "Ukraine",
            "country_code": "UKR",
            "abbreviation": "KRU"
          }
        },
        {
          "rank": 352,
          "movement": -2,
          "points": 178,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:54903",
            "name": "Karlovskiy, Evgeny",
            "country": "Neutral",
            "abbreviation": "KAR"
          }
        },
        {
          "rank": 353,
          "movement": 29,
          "points": 177,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:182086",
            "name": "Bass, Finn",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "BAS"
          }
        },
        {
          "rank": 354,
          "movement": -3,
          "points": 176,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:855911",
            "name": "Hrazdil, Jan",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "HRA"
          }
        },
        {
          "rank": 355,
          "movement": -3,
          "points": 175,
          "competitions_played": 3,
          "competitor": {
            "id": "sr:competitor:90798",
            "name": "Halys, Quentin",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "HAL"
          }
        },
        {
          "rank": 356,
          "movement": -3,
          "points": 174,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:207777",
            "name": "Imamura, Masamichi",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "IMA"
          }
        },
        {
          "rank": 357,
          "movement": -3,
          "points": 173,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:679701",
            "name": "Gueymard Wayenburg, Sascha",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "GUE"
          }
        },
        {
          "rank": 358,
          "movement": -3,
          "points": 173,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:280559",
            "name": "Catini, Niccolo",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "CAT"
          }
        },
        {
          "rank": 359,
          "movement": -3,
          "points": 171,
          "competitions_played": 6,
          "competitor": {
            "id": "sr:competitor:309954",
            "name": "Droguet, Titouan",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "DRO"
          }
        },
        {
          "rank": 360,
          "movement": -3,
          "points": 171,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:750283",
            "name": "Isomura, Kokoro",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "ISO"
          }
        },
        {
          "rank": 361,
          "movement": -3,
          "points": 171,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:244388",
            "name": "Kalyanpur, Adil",
            "country": "India",
            "country_code": "IND",
            "abbreviation": "KAL"
          }
        },
        {
          "rank": 362,
          "movement": -3,
          "points": 171,
          "competitions_played": 33,
          "competitor": {
            "id": "sr:competitor:16852",
            "name": "Uzhylovskyi, Volodoymyr",
            "country": "Ukraine",
            "country_code": "UKR",
            "abbreviation": "UZV"
          }
        },
        {
          "rank": 363,
          "movement": 33,
          "points": 170,
          "competitions_played": 6,
          "competitor": {
            "id": "sr:competitor:49172",
            "name": "Dzumhur, Damir",
            "country": "Bosnia & Herzegovina",
            "country_code": "BIH",
            "abbreviation": "DZU"
          }
        },
        {
          "rank": 364,
          "movement": -4,
          "points": 169,
          "competitions_played": 8,
          "competitor": {
            "id": "sr:competitor:947875",
            "name": "Zhou, Yi",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "ZHO"
          }
        },
        {
          "rank": 365,
          "movement": -27,
          "points": 169,
          "competitions_played": 28,
          "competitor": {
            "id": "sr:competitor:681071",
            "name": "Ganta, Sai Karteek Reddy",
            "country": "India",
            "country_code": "IND",
            "abbreviation": "GAN"
          }
        },
        {
          "rank": 366,
          "movement": -3,
          "points": 168,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:130442",
            "name": "Rai, Ajeet",
            "country": "New Zealand",
            "country_code": "NZL",
            "abbreviation": "RAI"
          }
        },
        {
          "rank": 367,
          "movement": -3,
          "points": 167,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:43761",
            "name": "Collarini, Andrea",
            "country": "Argentina",
            "country_code": "ARG",
            "abbreviation": "COL"
          }
        },
        {
          "rank": 368,
          "movement": -7,
          "points": 167,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:215696",
            "name": "Schell, Niklas",
            "country": "Germany",
            "country_code": "DEU",
            "abbreviation": "SCH"
          }
        },
        {
          "rank": 369,
          "movement": -2,
          "points": 164,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:378220",
            "name": "Huertas Del Pino Cordova, Arklon",
            "country": "Peru",
            "country_code": "PER",
            "abbreviation": "HUE"
          }
        },
        {
          "rank": 370,
          "movement": -2,
          "points": 164,
          "competitions_played": 24,
          "competitor": {
            "id": "sr:competitor:116616",
            "name": "Clarke, Jay",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "CLA"
          }
        },
        {
          "rank": 371,
          "movement": -2,
          "points": 163,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:564952",
            "name": "Kusuhara, Yusuke",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "KUS"
          }
        },
        {
          "rank": 372,
          "movement": -2,
          "points": 162,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:497320",
            "name": "Visker, Niels",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "VIS"
          }
        },
        {
          "rank": 373,
          "movement": 108,
          "points": 161,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:457059",
            "name": "Montes-de la Torre, Inaki",
            "country": "Spain",
            "country_code": "ESP",
            "abbreviation": "MON"
          }
        },
        {
          "rank": 374,
          "movement": -3,
          "points": 160,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:138712",
            "name": "Oradini, Giovanni",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "ORA"
          }
        },
        {
          "rank": 375,
          "movement": -3,
          "points": 159,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:298118",
            "name": "Summers, Matthew",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "SUM"
          }
        },
        {
          "rank": 376,
          "movement": -2,
          "points": 158,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:263857",
            "name": "De Krom, Michiel",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "DE"
          }
        },
        {
          "rank": 377,
          "movement": -2,
          "points": 156,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:976405",
            "name": "Taguchi, Ryotaro",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "TAG"
          }
        },
        {
          "rank": 378,
          "movement": -2,
          "points": 156,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:51100",
            "name": "Roca Batalla, Oriol",
            "country": "Spain",
            "country_code": "ESP",
            "abbreviation": "ROC"
          }
        },
        {
          "rank": 379,
          "movement": -2,
          "points": 156,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:215492",
            "name": "Cui, Jie",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "CUI"
          }
        },
        {
          "rank": 380,
          "movement": -1,
          "points": 155,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:785974",
            "name": "La Serna, Juan Manuel",
            "country": "Argentina",
            "country_code": "ARG",
            "abbreviation": "LA"
          }
        },
        {
          "rank": 381,
          "movement": -1,
          "points": 153,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:22962",
            "name": "Jebavy, Roman",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "JEB"
          }
        },
        {
          "rank": 382,
          "movement": -4,
          "points": 153,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:620338",
            "name": "Sharipov, Marat",
            "country": "Neutral",
            "abbreviation": "SHA"
          }
        },
        {
          "rank": 383,
          "movement": -21,
          "points": 153,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:385204",
            "name": "Verbin, Pavel",
            "country": "Neutral",
            "abbreviation": "VER"
          }
        },
        {
          "rank": 384,
          "movement": -3,
          "points": 152,
          "competitions_played": 8,
          "competitor": {
            "id": "sr:competitor:240876",
            "name": "Crawford, Oliver",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "CRA"
          }
        },
        {
          "rank": 385,
          "movement": -2,
          "points": 151,
          "competitions_played": 7,
          "competitor": {
            "id": "sr:competitor:57021",
            "name": "Kovalik, Jozef",
            "country": "Slovakia",
            "country_code": "SVK",
            "abbreviation": "KOV"
          }
        },
        {
          "rank": 386,
          "movement": -2,
          "points": 151,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:644676",
            "name": "Milev, Yanaki",
            "country": "Bulgaria",
            "country_code": "BGR",
            "abbreviation": "MIL"
          }
        },
        {
          "rank": 387,
          "movement": -2,
          "points": 151,
          "competitions_played": 32,
          "competitor": {
            "id": "sr:competitor:208123",
            "name": "Maginley, Jody",
            "country": "Antigua and Barbuda",
            "country_code": "ATG",
            "abbreviation": "MAG"
          }
        },
        {
          "rank": 388,
          "movement": -2,
          "points": 150,
          "competitions_played": 2,
          "competitor": {
            "id": "sr:competitor:763108",
            "name": "Mensik, Jakub",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "MEN"
          }
        },
        {
          "rank": 389,
          "movement": -2,
          "points": 150,
          "competitions_played": 3,
          "competitor": {
            "id": "sr:competitor:339377",
            "name": "Lehecka, Jiri",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "LEH"
          }
        },
        {
          "rank": 390,
          "movement": -1,
          "points": 150,
          "competitions_played": 6,
          "competitor": {
            "id": "sr:competitor:185388",
            "name": "Humbert, Ugo",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "HUM"
          }
        },
        {
          "rank": 391,
          "movement": -3,
          "points": 150,
          "competitions_played": 6,
          "competitor": {
            "id": "sr:competitor:294300",
            "name": "Nakashima, Brandon",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "NAK"
          }
        },
        {
          "rank": 392,
          "movement": -2,
          "points": 150,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:194668",
            "name": "Wenger, Damien",
            "country": "Switzerland",
            "country_code": "CHE",
            "abbreviation": "WEN"
          }
        },
        {
          "rank": 393,
          "movement": -1,
          "points": 149,
          "competitions_played": 6,
          "competitor": {
            "id": "sr:competitor:565070",
            "name": "Monday, Johannus",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "MON"
          }
        },
        {
          "rank": 394,
          "movement": -1,
          "points": 149,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:205773",
            "name": "Sanchez Jover, Carlos",
            "country": "Spain",
            "country_code": "ESP",
            "abbreviation": "SAN"
          }
        },
        {
          "rank": 395,
          "movement": -1,
          "points": 148,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:210502",
            "name": "Kopp, Sandro",
            "country": "Austria",
            "country_code": "AUT",
            "abbreviation": "KOP"
          }
        },
        {
          "rank": 396,
          "movement": -1,
          "points": 148,
          "competitions_played": 25,
          "competitor": {
            "id": "sr:competitor:272245",
            "name": "Latinovic, Stefan",
            "country": "Serbia",
            "country_code": "SRB",
            "abbreviation": "LAT"
          }
        },
        {
          "rank": 397,
          "movement": 0,
          "points": 145,
          "competitions_played": 9,
          "competitor": {
            "id": "sr:competitor:515510",
            "name": "Heide, Gustavo",
            "country": "Brazil",
            "country_code": "BRA",
            "abbreviation": "HEI"
          }
        },
        {
          "rank": 398,
          "movement": 0,
          "points": 145,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:65606",
            "name": "Agamenone, Franco",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "AGA"
          }
        },
        {
          "rank": 399,
          "movement": 0,
          "points": 145,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:138528",
            "name": "Mejia, Nicolas",
            "country": "Colombia",
            "country_code": "COL",
            "abbreviation": "MEJ"
          }
        },
        {
          "rank": 400,
          "movement": 0,
          "points": 144,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:359608",
            "name": "Maestrelli, Francesco",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "MAE"
          }
        },
        {
          "rank": 401,
          "movement": 0,
          "points": 144,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:16781",
            "name": "Sharan, Divij",
            "country": "India",
            "country_code": "IND",
            "abbreviation": "SHA"
          }
        },
        {
          "rank": 402,
          "movement": 0,
          "points": 143,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:321667",
            "name": "Mayot, Harold",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "MAY"
          }
        },
        {
          "rank": 403,
          "movement": 0,
          "points": 143,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:50901",
            "name": "Popko, Dmitry",
            "country": "Kazakhstan",
            "country_code": "KAZ",
            "abbreviation": "POP"
          }
        },
        {
          "rank": 404,
          "movement": 15,
          "points": 143,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:447733",
            "name": "Hands, Tom",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "HAN"
          }
        },
        {
          "rank": 405,
          "movement": -1,
          "points": 141,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:439474",
            "name": "Jermar, Jan",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "JER"
          }
        },
        {
          "rank": 406,
          "movement": 0,
          "points": 141,
          "competitions_played": 27,
          "competitor": {
            "id": "sr:competitor:156826",
            "name": "van Wyk, Kris",
            "country": "South Africa",
            "country_code": "ZAF",
            "abbreviation": "VAN"
          }
        },
        {
          "rank": 407,
          "movement": 0,
          "points": 140,
          "competitions_played": 4,
          "competitor": {
            "id": "sr:competitor:405969",
            "name": "Paulson, Andrew",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "PAU"
          }
        },
        {
          "rank": 408,
          "movement": 0,
          "points": 139,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:833418",
            "name": "Del Pino, Mateo",
            "country": "Argentina",
            "country_code": "ARG",
            "abbreviation": "DEL"
          }
        },
        {
          "rank": 409,
          "movement": 0,
          "points": 138,
          "competitions_played": 7,
          "competitor": {
            "id": "sr:competitor:121668",
            "name": "Meligeni Alves, Felipe",
            "country": "Brazil",
            "country_code": "BRA",
            "abbreviation": "MEL"
          }
        },
        {
          "rank": 410,
          "movement": 0,
          "points": 137,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:435758",
            "name": "Vanshelboim, Eric",
            "country": "Ukraine",
            "country_code": "UKR",
            "abbreviation": "VAN"
          }
        },
        {
          "rank": 411,
          "movement": 0,
          "points": 136,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:215778",
            "name": "Izquierdo Luque, Rafael",
            "country": "Spain",
            "country_code": "ESP",
            "abbreviation": "IZQ"
          }
        },
        {
          "rank": 412,
          "movement": 0,
          "points": 136,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:202681",
            "name": "Marrero Curbelo, Ivan",
            "country": "Spain",
            "country_code": "ESP",
            "abbreviation": "MAR"
          }
        },
        {
          "rank": 413,
          "movement": 0,
          "points": 136,
          "competitions_played": 24,
          "competitor": {
            "id": "sr:competitor:119126",
            "name": "Taylor, Adam (1991)",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "TAY"
          }
        },
        {
          "rank": 414,
          "movement": 0,
          "points": 135,
          "competitions_played": 1,
          "competitor": {
            "id": "sr:competitor:163636",
            "name": "Klein, Lukas",
            "country": "Slovakia",
            "country_code": "SVK",
            "abbreviation": "KLE"
          }
        },
        {
          "rank": 415,
          "movement": 1,
          "points": 135,
          "competitions_played": 7,
          "competitor": {
            "id": "sr:competitor:161262",
            "name": "Seyboth Wild, Thiago",
            "country": "Brazil",
            "country_code": "BRA",
            "abbreviation": "SEY"
          }
        },
        {
          "rank": 416,
          "movement": -1,
          "points": 135,
          "competitions_played": 7,
          "competitor": {
            "id": "sr:competitor:119248",
            "name": "Ruud, Casper",
            "country": "Norway",
            "country_code": "NOR",
            "abbreviation": "RUU"
          }
        },
        {
          "rank": 417,
          "movement": 0,
          "points": 135,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:54573",
            "name": "Coria, Federico",
            "country": "Argentina",
            "country_code": "ARG",
            "abbreviation": "COR"
          }
        },
        {
          "rank": 418,
          "movement": 0,
          "points": 135,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:345060",
            "name": "Kingsley, Cannon",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "KIN"
          }
        },
        {
          "rank": 419,
          "movement": 1,
          "points": 135,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:951223",
            "name": "Sanchez Quilez, Alejo",
            "country": "Spain",
            "country_code": "ESP",
            "abbreviation": "SAN"
          }
        },
        {
          "rank": 420,
          "movement": 1,
          "points": 135,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:256375",
            "name": "Jeong, Yeongseok",
            "country": "Republic of Korea",
            "country_code": "KOR",
            "abbreviation": "JEO"
          }
        },
        {
          "rank": 421,
          "movement": 2,
          "points": 134,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:524256",
            "name": "Beckley, Alec",
            "country": "South Africa",
            "country_code": "ZAF",
            "abbreviation": "BEC"
          }
        },
        {
          "rank": 422,
          "movement": -17,
          "points": 133,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:873679",
            "name": "Bondioli, Federico",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "BON"
          }
        },
        {
          "rank": 423,
          "movement": 3,
          "points": 131,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:96239",
            "name": "Durasovic, Viktor",
            "country": "Norway",
            "country_code": "NOR",
            "abbreviation": "DUR"
          }
        },
        {
          "rank": 424,
          "movement": 1,
          "points": 130,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:269535",
            "name": "Potenza, Luca",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "POT"
          }
        },
        {
          "rank": 425,
          "movement": 4,
          "points": 130,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:282183",
            "name": "Rottoli, Lorenzo",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "ROT"
          }
        },
        {
          "rank": 426,
          "movement": -2,
          "points": 130,
          "competitions_played": 28,
          "competitor": {
            "id": "sr:competitor:418163",
            "name": "Perfetti, Noah",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "PER"
          }
        },
        {
          "rank": 427,
          "movement": 0,
          "points": 129,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:48281",
            "name": "Rungkat, Christopher",
            "country": "Indonesia",
            "country_code": "IDN",
            "abbreviation": "RUN"
          }
        },
        {
          "rank": 428,
          "movement": 2,
          "points": 128,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:180446",
            "name": "Wessels, Louis",
            "country": "Germany",
            "country_code": "DEU",
            "abbreviation": "WES"
          }
        },
        {
          "rank": 429,
          "movement": 3,
          "points": 128,
          "competitions_played": 29,
          "competitor": {
            "id": "sr:competitor:404753",
            "name": "Saritas, Gokberk",
            "country": "Turkiye",
            "country_code": "TUR",
            "abbreviation": "SAR"
          }
        },
        {
          "rank": 430,
          "movement": 3,
          "points": 127,
          "competitions_played": 7,
          "competitor": {
            "id": "sr:competitor:104967",
            "name": "Brouwer, Gijs",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "BRO"
          }
        },
        {
          "rank": 431,
          "movement": 3,
          "points": 127,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:58783",
            "name": "Song, Min-Kyu",
            "country": "Republic of Korea",
            "country_code": "KOR",
            "abbreviation": "SON"
          }
        },
        {
          "rank": 432,
          "movement": -1,
          "points": 127,
          "competitions_played": 25,
          "competitor": {
            "id": "sr:competitor:100317",
            "name": "Turker, Mert Naci",
            "country": "Turkiye",
            "country_code": "TUR",
            "abbreviation": "TUR"
          }
        },
        {
          "rank": 433,
          "movement": 3,
          "points": 126,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:301896",
            "name": "Ovcharenko, Oleksandr",
            "country": "Ukraine",
            "country_code": "UKR",
            "abbreviation": "OVC"
          }
        },
        {
          "rank": 434,
          "movement": 3,
          "points": 126,
          "competitions_played": 24,
          "competitor": {
            "id": "sr:competitor:65992",
            "name": "Paz, Juan Pablo",
            "country": "Argentina",
            "country_code": "ARG",
            "abbreviation": "PAZ"
          }
        },
        {
          "rank": 435,
          "movement": -7,
          "points": 125,
          "competitions_played": 9,
          "competitor": {
            "id": "sr:competitor:177686",
            "name": "Barranco Cosano, Javier",
            "country": "Spain",
            "country_code": "ESP",
            "abbreviation": "BAR"
          }
        },
        {
          "rank": 436,
          "movement": 2,
          "points": 125,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:60592",
            "name": "Lee, Jeamoon",
            "country": "Republic of Korea",
            "country_code": "KOR",
            "abbreviation": "LEE"
          }
        },
        {
          "rank": 437,
          "movement": 2,
          "points": 125,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:283451",
            "name": "Rodriguez, Lorenzo Joaquin",
            "country": "Argentina",
            "country_code": "ARG",
            "abbreviation": "ROD"
          }
        },
        {
          "rank": 438,
          "movement": 15,
          "points": 124,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:114885",
            "name": "Nikles, Johan",
            "country": "Switzerland",
            "country_code": "CHE",
            "abbreviation": "NIK"
          }
        },
        {
          "rank": 439,
          "movement": 1,
          "points": 124,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:252233",
            "name": "Tang, Sheng",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "TAN"
          }
        },
        {
          "rank": 440,
          "movement": 1,
          "points": 124,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:15743",
            "name": "Istomin, Denis",
            "country": "Uzbekistan",
            "country_code": "UZB",
            "abbreviation": "IST"
          }
        },
        {
          "rank": 441,
          "movement": 2,
          "points": 124,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:137890",
            "name": "Vale, Duarte",
            "country": "Portugal",
            "country_code": "PRT",
            "abbreviation": "VAL"
          }
        },
        {
          "rank": 442,
          "movement": 2,
          "points": 123,
          "competitions_played": 7,
          "competitor": {
            "id": "sr:competitor:283965",
            "name": "Suresh, Dhakshineswar",
            "country": "India",
            "country_code": "IND",
            "abbreviation": "SUR"
          }
        },
        {
          "rank": 443,
          "movement": 23,
          "points": 123,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:990785",
            "name": "Zheng, Zhan",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "ZHE"
          }
        },
        {
          "rank": 444,
          "movement": 2,
          "points": 123,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:57759",
            "name": "Oliveira, Gonzalo",
            "country": "Venezuela",
            "country_code": "VEN",
            "abbreviation": "OLI"
          }
        },
        {
          "rank": 445,
          "movement": 2,
          "points": 122,
          "competitions_played": 4,
          "competitor": {
            "id": "sr:competitor:71280",
            "name": "Kokkinakis, Thanasi",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "KOK"
          }
        },
        {
          "rank": 446,
          "movement": 2,
          "points": 122,
          "competitions_played": 6,
          "competitor": {
            "id": "sr:competitor:310974",
            "name": "De Jong, Jesper",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "DEJ"
          }
        },
        {
          "rank": 447,
          "movement": 2,
          "points": 122,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:88992",
            "name": "Muller, Alexandre",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "MUL"
          }
        },
        {
          "rank": 448,
          "movement": 7,
          "points": 122,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:570833",
            "name": "Rodriguez Rodriguez, Johan Alexander",
            "country": "Colombia",
            "country_code": "COL",
            "abbreviation": "ROD"
          }
        },
        {
          "rank": 449,
          "movement": 1,
          "points": 121,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:217038",
            "name": "Seeman, Johannes",
            "country": "Estonia",
            "country_code": "EST",
            "abbreviation": "SEE"
          }
        },
        {
          "rank": 450,
          "movement": 1,
          "points": 120,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:938667",
            "name": "Schwaerzler, Joel",
            "country": "Austria",
            "country_code": "AUT",
            "abbreviation": "SCH"
          }
        },
        {
          "rank": 451,
          "movement": 1,
          "points": 120,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:682903",
            "name": "Nakagawa, Shunsuke",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "NAK"
          }
        },
        {
          "rank": 452,
          "movement": 11,
          "points": 119,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:312728",
            "name": "Stewart, Hamish",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "STE"
          }
        },
        {
          "rank": 453,
          "movement": 58,
          "points": 119,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:297608",
            "name": "Hazawa, Shinji",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "HAZ"
          }
        },
        {
          "rank": 454,
          "movement": 0,
          "points": 119,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:181384",
            "name": "Sinha, Nitin Kumar",
            "country": "India",
            "country_code": "IND",
            "abbreviation": "SIN"
          }
        },
        {
          "rank": 455,
          "movement": -33,
          "points": 118,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:242556",
            "name": "McHugh, Aidan",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "MCH"
          }
        },
        {
          "rank": 456,
          "movement": 0,
          "points": 118,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:684577",
            "name": "Muller, Rik",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "MUL"
          }
        },
        {
          "rank": 457,
          "movement": 0,
          "points": 118,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:64790",
            "name": "Kalovelonis, Markos",
            "country": "Greece",
            "country_code": "GRC",
            "abbreviation": "KAL"
          }
        },
        {
          "rank": 458,
          "movement": 9,
          "points": 118,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:501410",
            "name": "Hignett, Liam",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "HIG"
          }
        },
        {
          "rank": 459,
          "movement": -1,
          "points": 118,
          "competitions_played": 50,
          "competitor": {
            "id": "sr:competitor:759758",
            "name": "Sakellaridis, Dimitris",
            "country": "Greece",
            "country_code": "GRC",
            "abbreviation": "SAK"
          }
        },
        {
          "rank": 460,
          "movement": -1,
          "points": 117,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:56361",
            "name": "Sels, Jelle",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "SEL"
          }
        },
        {
          "rank": 461,
          "movement": -1,
          "points": 117,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:130438",
            "name": "Ponwith, Nathan",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "PON"
          }
        },
        {
          "rank": 462,
          "movement": -1,
          "points": 117,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:57327",
            "name": "Domingues, Joao",
            "country": "Portugal",
            "country_code": "PRT",
            "abbreviation": "DOM"
          }
        },
        {
          "rank": 463,
          "movement": 931,
          "points": 116,
          "competitions_played": 4,
          "competitor": {
            "id": "sr:competitor:503814",
            "name": "Mochizuki, Shintaro",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "MOC"
          }
        },
        {
          "rank": 464,
          "movement": -2,
          "points": 116,
          "competitions_played": 6,
          "competitor": {
            "id": "sr:competitor:307112",
            "name": "Erel, Yanki",
            "country": "Turkiye",
            "country_code": "TUR",
            "abbreviation": "ERE"
          }
        },
        {
          "rank": 465,
          "movement": -23,
          "points": 116,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:978579",
            "name": "Ghazouani Durand, Yanis",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "GHA"
          }
        },
        {
          "rank": 466,
          "movement": -2,
          "points": 115,
          "competitions_played": 2,
          "competitor": {
            "id": "sr:competitor:997473",
            "name": "Bernet, Henry",
            "country": "Switzerland",
            "country_code": "CHE",
            "abbreviation": "BER"
          }
        },
        {
          "rank": 467,
          "movement": -2,
          "points": 115,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:107625",
            "name": "Janvier, Maxime",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "JAN"
          }
        },
        {
          "rank": 468,
          "movement": 26,
          "points": 115,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:609146",
            "name": "Okonkwo, Oliver",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "OKO"
          }
        },
        {
          "rank": 469,
          "movement": -1,
          "points": 115,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:152898",
            "name": "Gengel, Marek",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "GEN"
          }
        },
        {
          "rank": 470,
          "movement": 199,
          "points": 114,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:622876",
            "name": "Vallejo, Adolfo Daniel",
            "country": "Paraguay",
            "country_code": "PRY",
            "abbreviation": "VAL"
          }
        },
        {
          "rank": 471,
          "movement": -2,
          "points": 114,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:809324",
            "name": "Pacheco Mendez, Rodrigo",
            "country": "Mexico",
            "country_code": "MEX",
            "abbreviation": "PAC"
          }
        },
        {
          "rank": 472,
          "movement": -2,
          "points": 114,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:418167",
            "name": "Garcian, Axel",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "GAR"
          }
        },
        {
          "rank": 473,
          "movement": -2,
          "points": 113,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:54975",
            "name": "Casanova, Hernan",
            "country": "Argentina",
            "country_code": "ARG",
            "abbreviation": "CAS"
          }
        },
        {
          "rank": 474,
          "movement": -2,
          "points": 113,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:137892",
            "name": "Otegui, Juan Bautista",
            "country": "Argentina",
            "country_code": "ARG",
            "abbreviation": "OTE"
          }
        },
        {
          "rank": 475,
          "movement": -2,
          "points": 113,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:294248",
            "name": "Hellum Lilleengen, Lukas",
            "country": "Norway",
            "country_code": "NOR",
            "abbreviation": "HEL"
          }
        },
        {
          "rank": 476,
          "movement": -2,
          "points": 113,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:675167",
            "name": "Javia, Dev",
            "country": "India",
            "country_code": "IND",
            "abbreviation": "JAV"
          }
        },
        {
          "rank": 477,
          "movement": -2,
          "points": 113,
          "competitions_played": 28,
          "competitor": {
            "id": "sr:competitor:322729",
            "name": "Bueno Gil, Alvaro",
            "country": "Spain",
            "country_code": "ESP",
            "abbreviation": "BUE"
          }
        },
        {
          "rank": 478,
          "movement": -1,
          "points": 112,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:220932",
            "name": "Shin, Sanhui",
            "country": "Republic of Korea",
            "country_code": "KOR",
            "abbreviation": "SHI"
          }
        },
        {
          "rank": 479,
          "movement": -1,
          "points": 112,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:403357",
            "name": "Thayne, Wally",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "THA"
          }
        },
        {
          "rank": 480,
          "movement": -1,
          "points": 112,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:867575",
            "name": "Massard, Loann",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "MAS"
          }
        },
        {
          "rank": 481,
          "movement": -1,
          "points": 112,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:76251",
            "name": "Bobrov, Bogdan",
            "country": "Neutral",
            "abbreviation": "BOB"
          }
        },
        {
          "rank": 482,
          "movement": 56,
          "points": 112,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:350814",
            "name": "Vankan, Marlon",
            "country": "Germany",
            "country_code": "DEU",
            "abbreviation": "VAN"
          }
        },
        {
          "rank": 483,
          "movement": 61,
          "points": 111,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:423131",
            "name": "Picchione, Andrea",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "PIC"
          }
        },
        {
          "rank": 484,
          "movement": -2,
          "points": 111,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:199196",
            "name": "Sanchez Izquierdo, Nikolas",
            "country": "Spain",
            "country_code": "ESP",
            "abbreviation": "SAI"
          }
        },
        {
          "rank": 485,
          "movement": -2,
          "points": 111,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:327067",
            "name": "Beloborodko, Illya",
            "country": "Ukraine",
            "country_code": "UKR",
            "abbreviation": "BI"
          }
        },
        {
          "rank": 486,
          "movement": -2,
          "points": 110,
          "competitions_played": 4,
          "competitor": {
            "id": "sr:competitor:39711",
            "name": "Duckworth, James",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "DUC"
          }
        },
        {
          "rank": 487,
          "movement": -2,
          "points": 110,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:341218",
            "name": "Colson, Tibo",
            "country": "Belgium",
            "country_code": "BEL",
            "abbreviation": "COL"
          }
        },
        {
          "rank": 488,
          "movement": -12,
          "points": 110,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:382056",
            "name": "Bouquier, Arthur",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "BOU"
          }
        },
        {
          "rank": 489,
          "movement": -3,
          "points": 110,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:101157",
            "name": "Rybakov, Alex",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "RYB"
          }
        },
        {
          "rank": 490,
          "movement": -3,
          "points": 110,
          "competitions_played": 25,
          "competitor": {
            "id": "sr:competitor:390486",
            "name": "Farjat, Tomas",
            "country": "Argentina",
            "country_code": "ARG",
            "abbreviation": "FAR"
          }
        },
        {
          "rank": 491,
          "movement": -2,
          "points": 109,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:833442",
            "name": "Schiessl, Joao Eduardo",
            "country": "Brazil",
            "country_code": "BRA",
            "abbreviation": "SCH"
          }
        },
        {
          "rank": 492,
          "movement": -2,
          "points": 108,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:373348",
            "name": "Pucinelli de Almeida, Matheus",
            "country": "Brazil",
            "country_code": "BRA",
            "abbreviation": "PDA"
          }
        },
        {
          "rank": 493,
          "movement": 28,
          "points": 108,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:112987",
            "name": "Handel, Tim",
            "country": "Germany",
            "country_code": "DEU",
            "abbreviation": "HAN"
          }
        },
        {
          "rank": 494,
          "movement": -3,
          "points": 108,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:269523",
            "name": "Bax, Florent",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "BAX"
          }
        },
        {
          "rank": 495,
          "movement": -3,
          "points": 107,
          "competitions_played": 8,
          "competitor": {
            "id": "sr:competitor:113859",
            "name": "Bellier, Antoine",
            "country": "Switzerland",
            "country_code": "CHE",
            "abbreviation": "BEL"
          }
        },
        {
          "rank": 496,
          "movement": -3,
          "points": 107,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:268725",
            "name": "Ramskogler, Gregor",
            "country": "Austria",
            "country_code": "AUT",
            "abbreviation": "RAM"
          }
        },
        {
          "rank": 497,
          "movement": -2,
          "points": 107,
          "competitions_played": 27,
          "competitor": {
            "id": "sr:competitor:246745",
            "name": "Tajima, Naoki",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "TAJ"
          }
        },
        {
          "rank": 498,
          "movement": -63,
          "points": 106,
          "competitions_played": 5,
          "competitor": {
            "id": "sr:competitor:213170",
            "name": "Blanchet, Ugo",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "BLA"
          }
        },
        {
          "rank": 499,
          "movement": -3,
          "points": 106,
          "competitions_played": 9,
          "competitor": {
            "id": "sr:competitor:373852",
            "name": "Zink, Tyler",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "ZIN"
          }
        },
        {
          "rank": 500,
          "movement": -2,
          "points": 106,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:161874",
            "name": "Corwin, Felix",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "COR"
          }
        },
    
    
        {
          "rank": 1,
          "movement": 0,
          "points": 10750,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:72376",
            "name": "Siniakova, Katerina",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "SIN"
          }
        },
        {
          "rank": 2,
          "movement": 0,
          "points": 8165,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:74949",
            "name": "Routliffe, Erin",
            "country": "New Zealand",
            "country_code": "NZL",
            "abbreviation": "ROU"
          }
        },
        {
          "rank": 3,
          "movement": 0,
          "points": 7378,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:51387",
            "name": "Townsend, Taylor",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "TOW"
          }
        },
        {
          "rank": 4,
          "movement": 0,
          "points": 6805,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:43860",
            "name": "Dabrowski, Gabriela",
            "country": "Canada",
            "country_code": "CAN",
            "abbreviation": "DAB"
          }
        },
        {
          "rank": 5,
          "movement": 0,
          "points": 5850,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:64496",
            "name": "Ostapenko, Jelena",
            "country": "Latvia",
            "country_code": "LVA",
            "abbreviation": "OST"
          }
        },
        {
          "rank": 6,
          "movement": 4,
          "points": 5696,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:19202",
            "name": "Errani, Sara",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "ERR"
          }
        },
        {
          "rank": 7,
          "movement": 4,
          "points": 5625,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:69208",
            "name": "Paolini, Jasmine",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "PAO"
          }
        },
        {
          "rank": 8,
          "movement": -2,
          "points": 4930,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:41520",
            "name": "Kichenok, Lyudmyla",
            "country": "Ukraine",
            "country_code": "UKR",
            "abbreviation": "KIC"
          }
        },
        {
          "rank": 9,
          "movement": 0,
          "points": 4755,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:119670",
            "name": "Perez, Ellen",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "PER"
          }
        },
        {
          "rank": 10,
          "movement": -2,
          "points": 4696,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:18936",
            "name": "Hsieh, Su-Wei",
            "country": "Chinese Taipei",
            "country_code": "TPE",
            "abbreviation": "HSI"
          }
        },
        {
          "rank": 11,
          "movement": 1,
          "points": 4585,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:46084",
            "name": "Melichar-Martinez, Nicole",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "MEL"
          }
        },
        {
          "rank": 12,
          "movement": 1,
          "points": 4350,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:19932",
            "name": "Muhammad, Asia",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "MUH"
          }
        },
        {
          "rank": 13,
          "movement": 2,
          "points": 4325,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:48625",
            "name": "Chan, Hao-Ching",
            "country": "Chinese Taipei",
            "country_code": "TPE",
            "abbreviation": "CHA"
          }
        },
        {
          "rank": 14,
          "movement": -7,
          "points": 4278,
          "competitions_played": 24,
          "competitor": {
            "id": "sr:competitor:64021",
            "name": "Krawczyk, Desirae",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "KRA"
          }
        },
        {
          "rank": 15,
          "movement": 1,
          "points": 4215,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:66968",
            "name": "Kudermetova, Veronika",
            "country": "Neutral",
            "abbreviation": "KUD"
          }
        },
        {
          "rank": 16,
          "movement": 1,
          "points": 3945,
          "competitions_played": 29,
          "competitor": {
            "id": "sr:competitor:47810",
            "name": "Khromacheva, Irina",
            "country": "Neutral",
            "abbreviation": "KHR"
          }
        },
        {
          "rank": 17,
          "movement": 3,
          "points": 3890,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:37508",
            "name": "Siegemund, Laura",
            "country": "Germany",
            "country_code": "DEU",
            "abbreviation": "SIE"
          }
        },
        {
          "rank": 18,
          "movement": 0,
          "points": 3768,
          "competitions_played": 32,
          "competitor": {
            "id": "sr:competitor:19607",
            "name": "Zhang, Shuai",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "ZHA"
          }
        },
        {
          "rank": 19,
          "movement": 0,
          "points": 3751,
          "competitions_played": 32,
          "competitor": {
            "id": "sr:competitor:69718",
            "name": "Danilina, Anna",
            "country": "Kazakhstan",
            "country_code": "KAZ",
            "abbreviation": "DAN"
          }
        },
        {
          "rank": 20,
          "movement": 1,
          "points": 3655,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:78551",
            "name": "Mertens, Elise",
            "country": "Belgium",
            "country_code": "BEL",
            "abbreviation": "MER"
          }
        },
        {
          "rank": 21,
          "movement": -7,
          "points": 3625,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:123824",
            "name": "Dolehide, Caroline",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "DOL"
          }
        },
        {
          "rank": 22,
          "movement": 0,
          "points": 3521,
          "competitions_played": 7,
          "competitor": {
            "id": "sr:competitor:373352",
            "name": "Gauff, Coco",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "GAU"
          }
        },
        {
          "rank": 23,
          "movement": 1,
          "points": 3291,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:18354",
            "name": "Mattek-Sands, Bethanie",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "MAT"
          }
        },
        {
          "rank": 24,
          "movement": 2,
          "points": 3210,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:33593",
            "name": "Mladenovic, Kristina",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "MLA"
          }
        },
        {
          "rank": 25,
          "movement": -2,
          "points": 3174,
          "competitions_played": 25,
          "competitor": {
            "id": "sr:competitor:99131",
            "name": "Bucsa, Cristina",
            "country": "Spain",
            "country_code": "ESP",
            "abbreviation": "BUC"
          }
        },
        {
          "rank": 26,
          "movement": 4,
          "points": 3160,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:588071",
            "name": "Shnaider, Diana",
            "country": "Neutral",
            "abbreviation": "SHN"
          }
        },
        {
          "rank": 27,
          "movement": 0,
          "points": 3053,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:91960",
            "name": "Kenin, Sofia",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "KEN"
          }
        },
        {
          "rank": 28,
          "movement": 4,
          "points": 2989,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:871583",
            "name": "Andreeva, Mirra",
            "country": "Neutral",
            "abbreviation": "AND"
          }
        },
        {
          "rank": 29,
          "movement": 0,
          "points": 2891,
          "competitions_played": 27,
          "competitor": {
            "id": "sr:competitor:24431",
            "name": "Panova, Alexandra",
            "country": "Neutral",
            "abbreviation": "PAN"
          }
        },
        {
          "rank": 30,
          "movement": 1,
          "points": 2615,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:289507",
            "name": "Fernandez, Leylah Annie",
            "country": "Canada",
            "country_code": "CAN",
            "abbreviation": "FER"
          }
        },
        {
          "rank": 31,
          "movement": 17,
          "points": 2592,
          "competitions_played": 35,
          "competitor": {
            "id": "sr:competitor:182178",
            "name": "Wu, Fang-Hsien",
            "country": "Chinese Taipei",
            "country_code": "TPE",
            "abbreviation": "FAN"
          }
        },
        {
          "rank": 32,
          "movement": 20,
          "points": 2515,
          "competitions_played": 28,
          "competitor": {
            "id": "sr:competitor:150122",
            "name": "Jiang, Xinyu",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "JIA"
          }
        },
        {
          "rank": 33,
          "movement": 2,
          "points": 2381,
          "competitions_played": 29,
          "competitor": {
            "id": "sr:competitor:66432",
            "name": "Kato, Miyu",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "KAT"
          }
        },
        {
          "rank": 34,
          "movement": -1,
          "points": 2381,
          "competitions_played": 24,
          "competitor": {
            "id": "sr:competitor:153652",
            "name": "Guo, Hanyu",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "GUO"
          }
        },
        {
          "rank": 35,
          "movement": -1,
          "points": 2365,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:19655",
            "name": "Niculescu, Monica",
            "country": "Romania",
            "country_code": "ROU",
            "abbreviation": "NIC"
          }
        },
        {
          "rank": 36,
          "movement": 0,
          "points": 2358,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:43102",
            "name": "Babos, Timea",
            "country": "Hungary",
            "country_code": "HUN",
            "abbreviation": "BAB"
          }
        },
        {
          "rank": 37,
          "movement": -12,
          "points": 2358,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:50537",
            "name": "Schuurs, Demi",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "SCH"
          }
        },
        {
          "rank": 38,
          "movement": -1,
          "points": 2324,
          "competitions_played": 30,
          "competitor": {
            "id": "sr:competitor:166124",
            "name": "Olmos, Giuliana",
            "country": "Mexico",
            "country_code": "MEX",
            "abbreviation": "OLM"
          }
        },
        {
          "rank": 39,
          "movement": -1,
          "points": 2324,
          "competitions_played": 25,
          "competitor": {
            "id": "sr:competitor:49682",
            "name": "Kichenok, Nadiia",
            "country": "Ukraine",
            "country_code": "UKR",
            "abbreviation": "KIC"
          }
        },
        {
          "rank": 40,
          "movement": 0,
          "points": 2269,
          "competitions_played": 28,
          "competitor": {
            "id": "sr:competitor:129714",
            "name": "Nicholls, Olivia",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "NIC"
          }
        },
        {
          "rank": 41,
          "movement": -13,
          "points": 2248,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:96075",
            "name": "Stefani, Luisa",
            "country": "Brazil",
            "country_code": "BRA",
            "abbreviation": "STE"
          }
        },
        {
          "rank": 42,
          "movement": -1,
          "points": 2248,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:60392",
            "name": "Sorribes Tormo, Sara",
            "country": "Spain",
            "country_code": "ESP",
            "abbreviation": "SOR"
          }
        },
        {
          "rank": 43,
          "movement": -4,
          "points": 2223,
          "competitions_played": 29,
          "competitor": {
            "id": "sr:competitor:47801",
            "name": "Eikeri, Ulrikke",
            "country": "Norway",
            "country_code": "NOR",
            "abbreviation": "EIK"
          }
        },
        {
          "rank": 44,
          "movement": -2,
          "points": 2210,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:51481",
            "name": "Sutjiadi, Aldila",
            "country": "Indonesia",
            "country_code": "IDN",
            "abbreviation": "SUT"
          }
        },
        {
          "rank": 45,
          "movement": -2,
          "points": 2102,
          "competitions_played": 9,
          "competitor": {
            "id": "sr:competitor:60398",
            "name": "Krejcikova, Barbora",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "KRE"
          }
        },
        {
          "rank": 46,
          "movement": -2,
          "points": 2060,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:272217",
            "name": "Wang, Xinyu",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "WAN"
          }
        },
        {
          "rank": 47,
          "movement": -1,
          "points": 2052,
          "competitions_played": 32,
          "competitor": {
            "id": "sr:competitor:70784",
            "name": "Hozumi, Eri",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "HOZ"
          }
        },
        {
          "rank": 48,
          "movement": 1,
          "points": 2050,
          "competitions_played": 30,
          "competitor": {
            "id": "sr:competitor:43547",
            "name": "Aoyama, Shuko",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "AOY"
          }
        },
        {
          "rank": 49,
          "movement": -2,
          "points": 2015,
          "competitions_played": 28,
          "competitor": {
            "id": "sr:competitor:142996",
            "name": "Mihalikova, Tereza",
            "country": "Slovakia",
            "country_code": "SVK",
            "abbreviation": "MIH"
          }
        },
        {
          "rank": 50,
          "movement": 0,
          "points": 1975,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:44834",
            "name": "Pegula, Jessica",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "PEG"
          }
        },
        {
          "rank": 51,
          "movement": 0,
          "points": 1944,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:103901",
            "name": "Ruse, Elena-Gabriela",
            "country": "Romania",
            "country_code": "ROU",
            "abbreviation": "RUS"
          }
        },
        {
          "rank": 52,
          "movement": 1,
          "points": 1918,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:138452",
            "name": "Shibahara, Ena",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "SHI"
          }
        },
        {
          "rank": 53,
          "movement": 1,
          "points": 1845,
          "competitions_played": 3,
          "competitor": {
            "id": "sr:competitor:45835",
            "name": "Hunter, Storm",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "HUN"
          }
        },
        {
          "rank": 54,
          "movement": -9,
          "points": 1783,
          "competitions_played": 29,
          "competitor": {
            "id": "sr:competitor:19974",
            "name": "Xu, Yifan",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "YIF"
          }
        },
        {
          "rank": 55,
          "movement": 2,
          "points": 1723,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:47697",
            "name": "Zheng, Saisai",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "ZHE"
          }
        },
        {
          "rank": 56,
          "movement": 5,
          "points": 1718,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:157672",
            "name": "Stollar, Fanny",
            "country": "Hungary",
            "country_code": "HUN",
            "abbreviation": "STO"
          }
        },
        {
          "rank": 57,
          "movement": -1,
          "points": 1714,
          "competitions_played": 32,
          "competitor": {
            "id": "sr:competitor:60668",
            "name": "Ninomiya, Makoto",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "NIN"
          }
        },
        {
          "rank": 58,
          "movement": 0,
          "points": 1711,
          "competitions_played": 7,
          "competitor": {
            "id": "sr:competitor:278887",
            "name": "Kostyuk, Marta",
            "country": "Ukraine",
            "country_code": "UKR",
            "abbreviation": "KOS"
          }
        },
        {
          "rank": 59,
          "movement": 12,
          "points": 1666,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:59702",
            "name": "Haddad Maia, Beatriz",
            "country": "Brazil",
            "country_code": "BRA",
            "abbreviation": "HAD"
          }
        },
        {
          "rank": 60,
          "movement": -1,
          "points": 1614,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:128584",
            "name": "Samsonova, Liudmila",
            "country": "Neutral",
            "abbreviation": "SAM"
          }
        },
        {
          "rank": 61,
          "movement": -1,
          "points": 1612,
          "competitions_played": 30,
          "competitor": {
            "id": "sr:competitor:61606",
            "name": "Sizikova, Yana",
            "country": "Neutral",
            "abbreviation": "SIZ"
          }
        },
        {
          "rank": 62,
          "movement": 0,
          "points": 1500,
          "competitions_played": 28,
          "competitor": {
            "id": "sr:competitor:19731",
            "name": "Piter, Katarzyna",
            "country": "Poland",
            "country_code": "POL",
            "abbreviation": "PIT"
          }
        },
        {
          "rank": 63,
          "movement": 0,
          "points": 1437,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:53789",
            "name": "Dart, Harriet",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "DAR"
          }
        },
        {
          "rank": 64,
          "movement": 0,
          "points": 1416,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:135854",
            "name": "Neel, Ingrid",
            "country": "Estonia",
            "country_code": "EST",
            "abbreviation": "NEE"
          }
        },
        {
          "rank": 65,
          "movement": -10,
          "points": 1392,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:105463",
            "name": "Bouzkova, Marie",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "BOU"
          }
        },
        {
          "rank": 66,
          "movement": -1,
          "points": 1391,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:252223",
            "name": "Rakhimova, Kamilla",
            "country": "Neutral",
            "abbreviation": "RAK"
          }
        },
        {
          "rank": 67,
          "movement": -1,
          "points": 1351,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:23158",
            "name": "Stephens, Sloane",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "STE"
          }
        },
        {
          "rank": 68,
          "movement": 0,
          "points": 1336,
          "competitions_played": 31,
          "competitor": {
            "id": "sr:competitor:215476",
            "name": "Siskova, Anna",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "SIS"
          }
        },
        {
          "rank": 69,
          "movement": 0,
          "points": 1307,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:549759",
            "name": "Krueger, Ashlyn",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "KRU"
          }
        },
        {
          "rank": 70,
          "movement": 0,
          "points": 1298,
          "competitions_played": 31,
          "competitor": {
            "id": "sr:competitor:52695",
            "name": "Moratelli, Angelica",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "MOR"
          }
        },
        {
          "rank": 71,
          "movement": -4,
          "points": 1275,
          "competitions_played": 31,
          "competitor": {
            "id": "sr:competitor:37504",
            "name": "Kalashnikova, Oksana",
            "country": "Georgia",
            "country_code": "GEO",
            "abbreviation": "KAL"
          }
        },
        {
          "rank": 72,
          "movement": 0,
          "points": 1221,
          "competitions_played": 32,
          "competitor": {
            "id": "sr:competitor:69602",
            "name": "Lumsden, Maia",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "LUM"
          }
        },
        {
          "rank": 73,
          "movement": 0,
          "points": 1182,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:41524",
            "name": "Krunic, Aleksandra",
            "country": "Serbia",
            "country_code": "SRB",
            "abbreviation": "KA"
          }
        },
        {
          "rank": 74,
          "movement": 1,
          "points": 1147,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:41877",
            "name": "Yuan, Yue",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "YUA"
          }
        },
        {
          "rank": 75,
          "movement": 1,
          "points": 1141,
          "competitions_played": 31,
          "competitor": {
            "id": "sr:competitor:194106",
            "name": "Tang, Qianhui",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "TAN"
          }
        },
        {
          "rank": 76,
          "movement": 2,
          "points": 1040,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:42289",
            "name": "Linette, Magda",
            "country": "Poland",
            "country_code": "POL",
            "abbreviation": "LIN"
          }
        },
        {
          "rank": 77,
          "movement": 2,
          "points": 1027,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:286435",
            "name": "Gadecki, Olivia",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "GAD"
          }
        },
        {
          "rank": 78,
          "movement": 2,
          "points": 1004,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:256547",
            "name": "Parks, Alycia",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "PAR"
          }
        },
        {
          "rank": 79,
          "movement": 2,
          "points": 1000,
          "competitions_played": 29,
          "competitor": {
            "id": "sr:competitor:71754",
            "name": "Martins, Ingrid",
            "country": "Brazil",
            "country_code": "BRA",
            "abbreviation": "MAR"
          }
        },
        {
          "rank": 80,
          "movement": 6,
          "points": 1000,
          "competitions_played": 28,
          "competitor": {
            "id": "sr:competitor:48451",
            "name": "Cavalle-Reimers, Yvonne",
            "country": "Spain",
            "country_code": "ESP",
            "abbreviation": "CAV"
          }
        },
        {
          "rank": 81,
          "movement": 4,
          "points": 990,
          "competitions_played": 31,
          "competitor": {
            "id": "sr:competitor:168526",
            "name": "Appleton, Emily",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "APP"
          }
        },
        {
          "rank": 82,
          "movement": 1,
          "points": 981,
          "competitions_played": 32,
          "competitor": {
            "id": "sr:competitor:44977",
            "name": "Santamaria, Sabrina",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "SAN"
          }
        },
        {
          "rank": 83,
          "movement": -9,
          "points": 976,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:67759",
            "name": "Alexandrova, Ekaterina",
            "country": "Neutral",
            "abbreviation": "ALE"
          }
        },
        {
          "rank": 84,
          "movement": 0,
          "points": 975,
          "competitions_played": 31,
          "competitor": {
            "id": "sr:competitor:73542",
            "name": "Gleason, Quinn",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "GLE"
          }
        },
        {
          "rank": 85,
          "movement": -8,
          "points": 958,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:234150",
            "name": "Potapova, Anastasia",
            "country": "Neutral",
            "abbreviation": "POT"
          }
        },
        {
          "rank": 86,
          "movement": 1,
          "points": 934,
          "competitions_played": 34,
          "competitor": {
            "id": "sr:competitor:54175",
            "name": "Zimmermann, Kimberley",
            "country": "Belgium",
            "country_code": "BEL",
            "abbreviation": "ZIM"
          }
        },
        {
          "rank": 87,
          "movement": 1,
          "points": 934,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:111189",
            "name": "Zarazua, Renata",
            "country": "Mexico",
            "country_code": "MEX",
            "abbreviation": "ZAR"
          }
        },
        {
          "rank": 88,
          "movement": 1,
          "points": 924,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:52025",
            "name": "Wang, Yafan",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "WAN"
          }
        },
        {
          "rank": 89,
          "movement": 1,
          "points": 919,
          "competitions_played": 32,
          "competitor": {
            "id": "sr:competitor:51651",
            "name": "Rosatello, Camilla",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "ROS"
          }
        },
        {
          "rank": 90,
          "movement": 1,
          "points": 916,
          "competitions_played": 35,
          "competitor": {
            "id": "sr:competitor:121760",
            "name": "Anshba, Amina",
            "country": "Neutral",
            "abbreviation": "ANS"
          }
        },
        {
          "rank": 91,
          "movement": 1,
          "points": 906,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:401055",
            "name": "Noskova, Linda",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "NOS"
          }
        },
        {
          "rank": 92,
          "movement": 1,
          "points": 904,
          "competitions_played": 30,
          "competitor": {
            "id": "sr:competitor:182054",
            "name": "Skoch, Miriam",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "SKO"
          }
        },
        {
          "rank": 93,
          "movement": -11,
          "points": 871,
          "competitions_played": 8,
          "competitor": {
            "id": "sr:competitor:18298",
            "name": "Zvonareva, Vera",
            "country": "Neutral",
            "abbreviation": "ZVO"
          }
        },
        {
          "rank": 94,
          "movement": 1,
          "points": 861,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:173748",
            "name": "Detiuc, Anastasia",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "DET"
          }
        },
        {
          "rank": 95,
          "movement": 1,
          "points": 846,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:150574",
            "name": "Bondar, Anna",
            "country": "Hungary",
            "country_code": "HUN",
            "abbreviation": "BON"
          }
        },
        {
          "rank": 96,
          "movement": 1,
          "points": 844,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:41404",
            "name": "Watson, Heather",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "WAT"
          }
        },
        {
          "rank": 97,
          "movement": 3,
          "points": 836,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:42492",
            "name": "Kawa, Katarzyna",
            "country": "Poland",
            "country_code": "POL",
            "abbreviation": "KAW"
          }
        },
        {
          "rank": 98,
          "movement": 0,
          "points": 829,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:192130",
            "name": "Blinkova, Anna",
            "country": "Neutral",
            "abbreviation": "BLI"
          }
        },
        {
          "rank": 99,
          "movement": 20,
          "points": 816,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:360038",
            "name": "Stearns, Peyton",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "STE"
          }
        },
        {
          "rank": 100,
          "movement": -1,
          "points": 792,
          "competitions_played": 8,
          "competitor": {
            "id": "sr:competitor:318195",
            "name": "Parry, Diane",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "PAR"
          }
        },
        {
          "rank": 101,
          "movement": 0,
          "points": 782,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:72450",
            "name": "Hibino, Nao",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "HIB"
          }
        },
        {
          "rank": 102,
          "movement": 0,
          "points": 777,
          "competitions_played": 9,
          "competitor": {
            "id": "sr:competitor:88310",
            "name": "Sherif Ahmed Abdelaziz, Maiar",
            "country": "Egypt",
            "country_code": "EGY",
            "abbreviation": "SHE"
          }
        },
        {
          "rank": 103,
          "movement": 0,
          "points": 777,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:799304",
            "name": "Pridankina, Elena",
            "country": "Neutral",
            "abbreviation": "PRI"
          }
        },
        {
          "rank": 104,
          "movement": 0,
          "points": 772,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:227486",
            "name": "Zantedeschi, Aurora",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "ZAN"
          }
        },
        {
          "rank": 105,
          "movement": 2,
          "points": 766,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:45545",
            "name": "Putintseva, Yulia",
            "country": "Kazakhstan",
            "country_code": "KAZ",
            "abbreviation": "PUT"
          }
        },
        {
          "rank": 106,
          "movement": 0,
          "points": 760,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:210558",
            "name": "Jorge, Francisca",
            "country": "Portugal",
            "country_code": "PRT",
            "abbreviation": "JOR"
          }
        },
        {
          "rank": 107,
          "movement": -2,
          "points": 759,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:262759",
            "name": "Wang, Xiyu",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "WAN"
          }
        },
        {
          "rank": 108,
          "movement": 0,
          "points": 748,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:335171",
            "name": "Uchijima, Moyuka",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "UCH"
          }
        },
        {
          "rank": 109,
          "movement": 0,
          "points": 742,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:378340",
            "name": "Corley, Carmen",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "COR"
          }
        },
        {
          "rank": 110,
          "movement": 0,
          "points": 736,
          "competitions_played": 31,
          "competitor": {
            "id": "sr:competitor:51943",
            "name": "Strakhova, Valeriya",
            "country": "Ukraine",
            "country_code": "UKR",
            "abbreviation": "STR"
          }
        },
        {
          "rank": 111,
          "movement": 2,
          "points": 733,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:92879",
            "name": "Shymanovich, Iryna",
            "country": "Neutral",
            "abbreviation": "SHY"
          }
        },
        {
          "rank": 112,
          "movement": 0,
          "points": 727,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:215598",
            "name": "Vedder, Eva",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "VED"
          }
        },
        {
          "rank": 113,
          "movement": 3,
          "points": 724,
          "competitions_played": 34,
          "competitor": {
            "id": "sr:competitor:418583",
            "name": "Haverlag, Isabelle",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "HAV"
          }
        },
        {
          "rank": 114,
          "movement": 1,
          "points": 720,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:108621",
            "name": "Kempen, Magali",
            "country": "Belgium",
            "country_code": "BEL",
            "abbreviation": "KEM"
          }
        },
        {
          "rank": 115,
          "movement": 5,
          "points": 714,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:453301",
            "name": "Jorge, Matilde",
            "country": "Portugal",
            "country_code": "PRT",
            "abbreviation": "JOR"
          }
        },
        {
          "rank": 116,
          "movement": 1,
          "points": 699,
          "competitions_played": 33,
          "competitor": {
            "id": "sr:competitor:143140",
            "name": "Aney, Jessie",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "ANE"
          }
        },
        {
          "rank": 117,
          "movement": 1,
          "points": 698,
          "competitions_played": 27,
          "competitor": {
            "id": "sr:competitor:53288",
            "name": "Silva, Eden",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "SIL"
          }
        },
        {
          "rank": 118,
          "movement": 3,
          "points": 684,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:67430",
            "name": "Cascino, Estelle",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "CAS"
          }
        },
        {
          "rank": 119,
          "movement": -5,
          "points": 676,
          "competitions_played": 27,
          "competitor": {
            "id": "sr:competitor:49907",
            "name": "Murray Sharan, Samantha",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "MUS"
          }
        },
        {
          "rank": 120,
          "movement": 3,
          "points": 661,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:303814",
            "name": "Tikhonova, Anastasia",
            "country": "Neutral",
            "abbreviation": "TIK"
          }
        },
        {
          "rank": 121,
          "movement": 3,
          "points": 660,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:161270",
            "name": "Salden, Lara",
            "country": "Belgium",
            "country_code": "BEL",
            "abbreviation": "SAL"
          }
        },
        {
          "rank": 122,
          "movement": 3,
          "points": 659,
          "competitions_played": 31,
          "competitor": {
            "id": "sr:competitor:628178",
            "name": "Brooks, Madeleine",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "BRO"
          }
        },
        {
          "rank": 123,
          "movement": 3,
          "points": 656,
          "competitions_played": 25,
          "competitor": {
            "id": "sr:competitor:50915",
            "name": "Plipuech, Peangtarn",
            "country": "Thailand",
            "country_code": "THA",
            "abbreviation": "PLI"
          }
        },
        {
          "rank": 124,
          "movement": 3,
          "points": 650,
          "competitions_played": 4,
          "competitor": {
            "id": "sr:competitor:19546",
            "name": "Pavlyuchenkova, Anastasia",
            "country": "Neutral",
            "abbreviation": "PAV"
          }
        },
        {
          "rank": 125,
          "movement": 3,
          "points": 649,
          "competitions_played": 28,
          "competitor": {
            "id": "sr:competitor:87090",
            "name": "Chong, Eudice",
            "country": "Hong Kong, China",
            "country_code": "HKG",
            "abbreviation": "CHO"
          }
        },
        {
          "rank": 126,
          "movement": 5,
          "points": 628,
          "competitions_played": 4,
          "competitor": {
            "id": "sr:competitor:45902",
            "name": "Sasnovich, Aliaksandra",
            "country": "Neutral",
            "abbreviation": "SAS"
          }
        },
        {
          "rank": 127,
          "movement": 5,
          "points": 628,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:98607",
            "name": "Chang, Sophie",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "CHA"
          }
        },
        {
          "rank": 128,
          "movement": 1,
          "points": 627,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:118096",
            "name": "Papadakis, Lena",
            "country": "Germany",
            "country_code": "DEU",
            "abbreviation": "PAP"
          }
        },
        {
          "rank": 129,
          "movement": 4,
          "points": 617,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:473609",
            "name": "Kubka, Martyna",
            "country": "Poland",
            "country_code": "POL",
            "abbreviation": "KUB"
          }
        },
        {
          "rank": 130,
          "movement": 4,
          "points": 613,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:867519",
            "name": "Tsao, Chia Yi",
            "country": "Chinese Taipei",
            "country_code": "TPE",
            "abbreviation": "TSA"
          }
        },
        {
          "rank": 131,
          "movement": 5,
          "points": 605,
          "competitions_played": 5,
          "competitor": {
            "id": "sr:competitor:179146",
            "name": "Kalinskaya, Anna",
            "country": "Neutral",
            "abbreviation": "KAL"
          }
        },
        {
          "rank": 132,
          "movement": 5,
          "points": 601,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:64085",
            "name": "Pigossi, Laura",
            "country": "Brazil",
            "country_code": "BRA",
            "abbreviation": "PIG"
          }
        },
        {
          "rank": 133,
          "movement": 2,
          "points": 595,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:52489",
            "name": "Schoofs, Bibiane",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "SCH"
          }
        },
        {
          "rank": 134,
          "movement": 5,
          "points": 589,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:256447",
            "name": "Monnet, Carole",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "MON"
          }
        },
        {
          "rank": 135,
          "movement": 3,
          "points": 585,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:771430",
            "name": "Naef, Celine",
            "country": "Switzerland",
            "country_code": "CHE",
            "abbreviation": "NAE"
          }
        },
        {
          "rank": 136,
          "movement": 11,
          "points": 574,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:345070",
            "name": "Arseneault, Ariana",
            "country": "Canada",
            "country_code": "CAN",
            "abbreviation": "ARS"
          }
        },
        {
          "rank": 137,
          "movement": 3,
          "points": 570,
          "competitions_played": 29,
          "competitor": {
            "id": "sr:competitor:61526",
            "name": "Thombare, Prarthana",
            "country": "India",
            "country_code": "IND",
            "abbreviation": "THO"
          }
        },
        {
          "rank": 138,
          "movement": -8,
          "points": 564,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:235260",
            "name": "Chwalinska, Maja",
            "country": "Poland",
            "country_code": "POL",
            "abbreviation": "CHW"
          }
        },
        {
          "rank": 139,
          "movement": 2,
          "points": 563,
          "competitions_played": 6,
          "competitor": {
            "id": "sr:competitor:72758",
            "name": "Cristian, Jaqueline",
            "country": "Romania",
            "country_code": "ROU",
            "abbreviation": "CRI"
          }
        },
        {
          "rank": 140,
          "movement": -18,
          "points": 562,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:19847",
            "name": "Rus, Arantxa",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "RUS"
          }
        },
        {
          "rank": 141,
          "movement": 1,
          "points": 560,
          "competitions_played": 2,
          "competitor": {
            "id": "sr:competitor:228418",
            "name": "Navarro, Emma",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "NAV"
          }
        },
        {
          "rank": 142,
          "movement": 1,
          "points": 560,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:297588",
            "name": "Romero Gormaz, Leyre",
            "country": "Spain",
            "country_code": "ESP",
            "abbreviation": "ROM"
          }
        },
        {
          "rank": 143,
          "movement": 1,
          "points": 559,
          "competitions_played": 32,
          "competitor": {
            "id": "sr:competitor:448121",
            "name": "Rogers, Anna",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "ROG"
          }
        },
        {
          "rank": 144,
          "movement": 1,
          "points": 553,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:226306",
            "name": "Corley, Ivana",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "COR"
          }
        },
        {
          "rank": 145,
          "movement": 1,
          "points": 552,
          "competitions_played": 5,
          "competitor": {
            "id": "sr:competitor:133662",
            "name": "Badosa, Paula",
            "country": "Spain",
            "country_code": "ESP",
            "abbreviation": "BAD"
          }
        },
        {
          "rank": 146,
          "movement": 3,
          "points": 542,
          "competitions_played": 6,
          "competitor": {
            "id": "sr:competitor:373354",
            "name": "Cocciaretto, Elisabetta",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "COC"
          }
        },
        {
          "rank": 147,
          "movement": 3,
          "points": 541,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:147506",
            "name": "Fourlis, Jaimee",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "FOU"
          }
        },
        {
          "rank": 148,
          "movement": 3,
          "points": 532,
          "competitions_played": 24,
          "competitor": {
            "id": "sr:competitor:92877",
            "name": "Fossa Huergo, Nicole",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "FOS"
          }
        },
        {
          "rank": 149,
          "movement": 3,
          "points": 532,
          "competitions_played": 27,
          "competitor": {
            "id": "sr:competitor:99429",
            "name": "Hule, Petra",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "HUL"
          }
        },
        {
          "rank": 150,
          "movement": 3,
          "points": 527,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:369524",
            "name": "Erjavec, Veronika",
            "country": "Slovenia",
            "country_code": "SVN",
            "abbreviation": "ERJ"
          }
        },
        {
          "rank": 151,
          "movement": 4,
          "points": 523,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:227390",
            "name": "Brancaccio, Nuria",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "BRA"
          }
        },
        {
          "rank": 152,
          "movement": 46,
          "points": 520,
          "competitions_played": 5,
          "competitor": {
            "id": "sr:competitor:45915",
            "name": "Yang, Zhaoxuan",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "YAN"
          }
        },
        {
          "rank": 153,
          "movement": 3,
          "points": 520,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:208125",
            "name": "Liang, En-Shuo",
            "country": "Chinese Taipei",
            "country_code": "TPE",
            "abbreviation": "LIA"
          }
        },
        {
          "rank": 154,
          "movement": -6,
          "points": 517,
          "competitions_played": 32,
          "competitor": {
            "id": "sr:competitor:46528",
            "name": "Perrin, Conny",
            "country": "Switzerland",
            "country_code": "CHE",
            "abbreviation": "PER"
          }
        },
        {
          "rank": 155,
          "movement": 2,
          "points": 510,
          "competitions_played": 25,
          "competitor": {
            "id": "sr:competitor:235252",
            "name": "Kozyreva, Maria",
            "country": "Neutral",
            "abbreviation": "KOZ"
          }
        },
        {
          "rank": 156,
          "movement": -62,
          "points": 505,
          "competitions_played": 7,
          "competitor": {
            "id": "sr:competitor:90664",
            "name": "Kalinina, Anhelina",
            "country": "Ukraine",
            "country_code": "UKR",
            "abbreviation": "KAL"
          }
        },
        {
          "rank": 157,
          "movement": 2,
          "points": 494,
          "competitions_played": 25,
          "competitor": {
            "id": "sr:competitor:148276",
            "name": "Zheng, Wushuang",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "ZHE"
          }
        },
        {
          "rank": 158,
          "movement": 2,
          "points": 492,
          "competitions_played": 25,
          "competitor": {
            "id": "sr:competitor:189384",
            "name": "Kulambayeva, Zhibek",
            "country": "Kazakhstan",
            "country_code": "KAZ",
            "abbreviation": "KUL"
          }
        },
        {
          "rank": 159,
          "movement": 2,
          "points": 489,
          "competitions_played": 33,
          "competitor": {
            "id": "sr:competitor:143146",
            "name": "Smith, Alana",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "SMI"
          }
        },
        {
          "rank": 160,
          "movement": 2,
          "points": 486,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:71284",
            "name": "Bains, Naiktha",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "BAI"
          }
        },
        {
          "rank": 161,
          "movement": 55,
          "points": 484,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:776340",
            "name": "Joint, Maya",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "JOI"
          }
        },
        {
          "rank": 162,
          "movement": 1,
          "points": 476,
          "competitions_played": 29,
          "competitor": {
            "id": "sr:competitor:65610",
            "name": "Wagner, Anita",
            "country": "Bosnia & Herzegovina",
            "country_code": "BIH",
            "abbreviation": "WAG"
          }
        },
        {
          "rank": 163,
          "movement": -5,
          "points": 475,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:170880",
            "name": "Kononova, Maria",
            "country": "Neutral",
            "abbreviation": "KON"
          }
        },
        {
          "rank": 164,
          "movement": 1,
          "points": 475,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:137932",
            "name": "Mikulskyte, Justina",
            "country": "Lithuania",
            "country_code": "LTU",
            "abbreviation": "MIK"
          }
        },
        {
          "rank": 165,
          "movement": 1,
          "points": 474,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:137990",
            "name": "Failla, Jessica",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "FAI"
          }
        },
        {
          "rank": 166,
          "movement": 1,
          "points": 474,
          "competitions_played": 44,
          "competitor": {
            "id": "sr:competitor:325837",
            "name": "Sakellaridi, Sapfo",
            "country": "Greece",
            "country_code": "GRC",
            "abbreviation": "SAK"
          }
        },
        {
          "rank": 167,
          "movement": -13,
          "points": 471,
          "competitions_played": 27,
          "competitor": {
            "id": "sr:competitor:46428",
            "name": "Maleckova, Jesika",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "MAL"
          }
        },
        {
          "rank": 168,
          "movement": -4,
          "points": 465,
          "competitions_played": 3,
          "competitor": {
            "id": "sr:competitor:42339",
            "name": "Garcia, Caroline",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "GAR"
          }
        },
        {
          "rank": 169,
          "movement": 1,
          "points": 461,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:120666",
            "name": "Stojanovic, Nina",
            "country": "Serbia",
            "country_code": "SRB",
            "abbreviation": "STO"
          }
        },
        {
          "rank": 170,
          "movement": -2,
          "points": 459,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:102637",
            "name": "McAdoo, Rasheeda",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "MCA"
          }
        },
        {
          "rank": 171,
          "movement": 0,
          "points": 457,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:119216",
            "name": "Herrero Linana, Alicia",
            "country": "Spain",
            "country_code": "ESP",
            "abbreviation": "HER"
          }
        },
        {
          "rank": 172,
          "movement": -3,
          "points": 456,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:250285",
            "name": "Falkowska, Weronika",
            "country": "Poland",
            "country_code": "POL",
            "abbreviation": "FAL"
          }
        },
        {
          "rank": 173,
          "movement": -1,
          "points": 451,
          "competitions_played": 5,
          "competitor": {
            "id": "sr:competitor:569013",
            "name": "Fernandez, Bianca Jolie",
            "country": "Canada",
            "country_code": "CAN",
            "abbreviation": "FER"
          }
        },
        {
          "rank": 174,
          "movement": -1,
          "points": 450,
          "competitions_played": 29,
          "competitor": {
            "id": "sr:competitor:245673",
            "name": "Feng, Shuo",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "FEN"
          }
        },
        {
          "rank": 175,
          "movement": -1,
          "points": 442,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:87834",
            "name": "Hon, Priscilla",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "HON"
          }
        },
        {
          "rank": 176,
          "movement": 4,
          "points": 442,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:215806",
            "name": "Hewitt, Dalayna",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "HEW"
          }
        },
        {
          "rank": 177,
          "movement": -2,
          "points": 441,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:91916",
            "name": "Grey, Sarah Beth",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "GRE"
          }
        },
        {
          "rank": 178,
          "movement": -2,
          "points": 440,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:105099",
            "name": "Birrell, Kimberly",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "BIR"
          }
        },
        {
          "rank": 179,
          "movement": -2,
          "points": 438,
          "competitions_played": 27,
          "competitor": {
            "id": "sr:competitor:45827",
            "name": "Lechemia, Elixane",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "LEC"
          }
        },
        {
          "rank": 180,
          "movement": -2,
          "points": 437,
          "competitions_played": 25,
          "competitor": {
            "id": "sr:competitor:206995",
            "name": "Rosca, Christina",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "ROS"
          }
        },
        {
          "rank": 181,
          "movement": -2,
          "points": 437,
          "competitions_played": 27,
          "competitor": {
            "id": "sr:competitor:805538",
            "name": "Cross, Kayla",
            "country": "Canada",
            "country_code": "CAN",
            "abbreviation": "CRO"
          }
        },
        {
          "rank": 182,
          "movement": -1,
          "points": 432,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:82609",
            "name": "Grammatikopoulou, Valentini",
            "country": "Greece",
            "country_code": "GRC",
            "abbreviation": "GRA"
          }
        },
        {
          "rank": 183,
          "movement": 10,
          "points": 430,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:160190",
            "name": "Hartono, Arianne",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "HAR"
          }
        },
        {
          "rank": 184,
          "movement": -2,
          "points": 428,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:319455",
            "name": "Baptiste, Hailey",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "BAP"
          }
        },
        {
          "rank": 185,
          "movement": -2,
          "points": 425,
          "competitions_played": 8,
          "competitor": {
            "id": "sr:competitor:242630",
            "name": "Osorio, Camila",
            "country": "Colombia",
            "country_code": "COL",
            "abbreviation": "OSO"
          }
        },
        {
          "rank": 186,
          "movement": -2,
          "points": 425,
          "competitions_played": 35,
          "competitor": {
            "id": "sr:competitor:41359",
            "name": "Yashina, Ekaterina",
            "country": "Neutral",
            "abbreviation": "YAS"
          }
        },
        {
          "rank": 187,
          "movement": -2,
          "points": 422,
          "competitions_played": 7,
          "competitor": {
            "id": "sr:competitor:608348",
            "name": "Kupres, Mia",
            "country": "Canada",
            "country_code": "CAN",
            "abbreviation": "KUP"
          }
        },
        {
          "rank": 188,
          "movement": -2,
          "points": 421,
          "competitions_played": 28,
          "competitor": {
            "id": "sr:competitor:310984",
            "name": "Sato, Naho",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "SAT"
          }
        },
        {
          "rank": 189,
          "movement": -2,
          "points": 419,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:70728",
            "name": "Bhosale, Rutuja",
            "country": "India",
            "country_code": "IND",
            "abbreviation": "BHO"
          }
        },
        {
          "rank": 190,
          "movement": -2,
          "points": 419,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:195408",
            "name": "Shimizu, Ayano",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "SHI"
          }
        },
        {
          "rank": 191,
          "movement": -2,
          "points": 417,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:448081",
            "name": "Noha Akugue, Noma",
            "country": "Germany",
            "country_code": "DEU",
            "abbreviation": "NOH"
          }
        },
        {
          "rank": 192,
          "movement": -2,
          "points": 414,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:52183",
            "name": "Bara, Irina Maria",
            "country": "Romania",
            "country_code": "ROU",
            "abbreviation": "BARA"
          }
        },
        {
          "rank": 193,
          "movement": 3,
          "points": 413,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:789688",
            "name": "Ngounoue, Clervie",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "NGO"
          }
        },
        {
          "rank": 194,
          "movement": -3,
          "points": 407,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:119874",
            "name": "Ibbou, Ines",
            "country": "Algeria",
            "country_code": "DZA",
            "abbreviation": "IBB"
          }
        },
        {
          "rank": 195,
          "movement": -3,
          "points": 405,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:119410",
            "name": "Krywoj, Melany Solange",
            "country": "Argentina",
            "country_code": "ARG",
            "abbreviation": "KRY"
          }
        },
        {
          "rank": 196,
          "movement": -2,
          "points": 403,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:45139",
            "name": "Papamichail, Despina",
            "country": "Greece",
            "country_code": "GRC",
            "abbreviation": "PAP"
          }
        },
        {
          "rank": 197,
          "movement": -2,
          "points": 402,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:110055",
            "name": "Bronzetti, Lucia",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "BRO"
          }
        },
        {
          "rank": 198,
          "movement": -1,
          "points": 401,
          "competitions_played": 27,
          "competitor": {
            "id": "sr:competitor:64315",
            "name": "Kuwata, Hiroko",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "KUW"
          }
        },
        {
          "rank": 199,
          "movement": 0,
          "points": 399,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:97031",
            "name": "Christofi, Eleni",
            "country": "Greece",
            "country_code": "GRC",
            "abbreviation": "CHR"
          }
        },
        {
          "rank": 200,
          "movement": 70,
          "points": 396,
          "competitions_played": 9,
          "competitor": {
            "id": "sr:competitor:675189",
            "name": "Preston, Taylah",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "PRE"
          }
        },
        {
          "rank": 201,
          "movement": -1,
          "points": 394,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:414533",
            "name": "Abbagnato, Anastasia",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "ABB"
          }
        },
        {
          "rank": 202,
          "movement": -1,
          "points": 394,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:93657",
            "name": "Karamoko, Naima",
            "country": "Switzerland",
            "country_code": "CHE",
            "abbreviation": "KAR"
          }
        },
        {
          "rank": 203,
          "movement": -1,
          "points": 394,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:183957",
            "name": "Kobori, Momoko",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "KOB"
          }
        },
        {
          "rank": 204,
          "movement": -1,
          "points": 390,
          "competitions_played": 4,
          "competitor": {
            "id": "sr:competitor:67757",
            "name": "Pera, Bernarda",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "PER"
          }
        },
        {
          "rank": 205,
          "movement": -1,
          "points": 387,
          "competitions_played": 28,
          "competitor": {
            "id": "sr:competitor:46625",
            "name": "Raina, Ankita",
            "country": "India",
            "country_code": "IND",
            "abbreviation": "RAI"
          }
        },
        {
          "rank": 206,
          "movement": -1,
          "points": 387,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:156040",
            "name": "Cho, I-Hsuan",
            "country": "Chinese Taipei",
            "country_code": "TPE",
            "abbreviation": "CHO"
          }
        },
        {
          "rank": 206,
          "movement": -1,
          "points": 387,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:210670",
            "name": "Cho, Yi Tsen",
            "country": "Chinese Taipei",
            "country_code": "TPE",
            "abbreviation": "CHO"
          }
        },
        {
          "rank": 208,
          "movement": -1,
          "points": 387,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:203893",
            "name": "Kucmova, Aneta",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "KUC"
          }
        },
        {
          "rank": 209,
          "movement": -1,
          "points": 385,
          "competitions_played": 34,
          "competitor": {
            "id": "sr:competitor:59762",
            "name": "Barnett, Alicia",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "BAR"
          }
        },
        {
          "rank": 210,
          "movement": -1,
          "points": 385,
          "competitions_played": 25,
          "competitor": {
            "id": "sr:competitor:378144",
            "name": "Karatancheva, Lia",
            "country": "Bulgaria",
            "country_code": "BGR",
            "abbreviation": "KAR"
          }
        },
        {
          "rank": 211,
          "movement": 0,
          "points": 383,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:385206",
            "name": "Radisic, Nika",
            "country": "Slovenia",
            "country_code": "SVN",
            "abbreviation": "RAD"
          }
        },
        {
          "rank": 212,
          "movement": 34,
          "points": 380,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:52533",
            "name": "Jakupovic, Dalila",
            "country": "Slovenia",
            "country_code": "SVN",
            "abbreviation": "JAK"
          }
        },
        {
          "rank": 213,
          "movement": 0,
          "points": 378,
          "competitions_played": 8,
          "competitor": {
            "id": "sr:competitor:49118",
            "name": "Harrison, Catherine",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "HAR"
          }
        },
        {
          "rank": 214,
          "movement": 3,
          "points": 378,
          "competitions_played": 24,
          "competitor": {
            "id": "sr:competitor:353358",
            "name": "Tran, Lian",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "TRA"
          }
        },
        {
          "rank": 215,
          "movement": -5,
          "points": 377,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:676251",
            "name": "Wuerth, Tara",
            "country": "Croatia",
            "country_code": "HRV",
            "abbreviation": "WUR"
          }
        },
        {
          "rank": 216,
          "movement": 7,
          "points": 377,
          "competitions_played": 28,
          "competitor": {
            "id": "sr:competitor:244216",
            "name": "Giavara, Haley",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "GIA"
          }
        },
        {
          "rank": 217,
          "movement": -3,
          "points": 375,
          "competitions_played": 31,
          "competitor": {
            "id": "sr:competitor:80427",
            "name": "Osborne, Alexandra",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "OSB"
          }
        },
        {
          "rank": 218,
          "movement": -3,
          "points": 373,
          "competitions_played": 9,
          "competitor": {
            "id": "sr:competitor:110299",
            "name": "Zidansek, Tamara",
            "country": "Slovenia",
            "country_code": "SVN",
            "abbreviation": "ZID"
          }
        },
        {
          "rank": 219,
          "movement": -1,
          "points": 368,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:79443",
            "name": "Cabrera, Lizette",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "CAB"
          }
        },
        {
          "rank": 220,
          "movement": -1,
          "points": 367,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:26120",
            "name": "Marino, Rebecca",
            "country": "Canada",
            "country_code": "CAN",
            "abbreviation": "MAR"
          }
        },
        {
          "rank": 221,
          "movement": -1,
          "points": 366,
          "competitions_played": 24,
          "competitor": {
            "id": "sr:competitor:260987",
            "name": "Osuigwe, Whitney",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "OSU"
          }
        },
        {
          "rank": 222,
          "movement": -1,
          "points": 365,
          "competitions_played": 5,
          "competitor": {
            "id": "sr:competitor:192108",
            "name": "Yastremska, Dayana",
            "country": "Ukraine",
            "country_code": "UKR",
            "abbreviation": "YAS"
          }
        },
        {
          "rank": 223,
          "movement": -1,
          "points": 365,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:568715",
            "name": "Semenistaja, Darja",
            "country": "Latvia",
            "country_code": "LVA",
            "abbreviation": "SEM"
          }
        },
        {
          "rank": 224,
          "movement": 0,
          "points": 361,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:190882",
            "name": "Aiava, Destanee",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "AIA"
          }
        },
        {
          "rank": 225,
          "movement": 0,
          "points": 353,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:41737",
            "name": "Jang, Su Jeong",
            "country": "Republic of Korea",
            "country_code": "KOR",
            "abbreviation": "JAN"
          }
        },
        {
          "rank": 226,
          "movement": 6,
          "points": 352,
          "competitions_played": 25,
          "competitor": {
            "id": "sr:competitor:290994",
            "name": "Wong, Hong Yi Cody",
            "country": "Hong Kong, China",
            "country_code": "HKG",
            "abbreviation": "WON"
          }
        },
        {
          "rank": 227,
          "movement": -1,
          "points": 352,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:416473",
            "name": "Reyngold, Ekaterina",
            "country": "Neutral",
            "abbreviation": "REY"
          }
        },
        {
          "rank": 228,
          "movement": -1,
          "points": 351,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:23688",
            "name": "Moore, Tara",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "MOO"
          }
        },
        {
          "rank": 229,
          "movement": -1,
          "points": 351,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:904005",
            "name": "Ibragimova, Alevtina",
            "country": "Neutral",
            "abbreviation": "IBR"
          }
        },
        {
          "rank": 230,
          "movement": -1,
          "points": 349,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:662615",
            "name": "Salkova, Dominika",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "SAL"
          }
        },
        {
          "rank": 231,
          "movement": -19,
          "points": 347,
          "competitions_played": 31,
          "competitor": {
            "id": "sr:competitor:88494",
            "name": "Christie, Freya",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "CHR"
          }
        },
        {
          "rank": 232,
          "movement": -2,
          "points": 344,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:762762",
            "name": "Seidel, Ella",
            "country": "Germany",
            "country_code": "DEU",
            "abbreviation": "SEI"
          }
        },
        {
          "rank": 233,
          "movement": -2,
          "points": 344,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:496316",
            "name": "Gimbrere, Jasmijn",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "GIM"
          }
        },
        {
          "rank": 234,
          "movement": 55,
          "points": 338,
          "competitions_played": 9,
          "competitor": {
            "id": "sr:competitor:115507",
            "name": "Bolsova, Aliona",
            "country": "Spain",
            "country_code": "ESP",
            "abbreviation": "BOL"
          }
        },
        {
          "rank": 235,
          "movement": -124,
          "points": 337,
          "competitions_played": 6,
          "competitor": {
            "id": "sr:competitor:152804",
            "name": "Vondrousova, Marketa",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "VON"
          }
        },
        {
          "rank": 236,
          "movement": -2,
          "points": 328,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:192572",
            "name": "Portillo Ramirez, Maria Jose",
            "country": "Mexico",
            "country_code": "MEX",
            "abbreviation": "POR"
          }
        },
        {
          "rank": 237,
          "movement": -4,
          "points": 327,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:505998",
            "name": "Zamarripa, Maribella",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "ZAM"
          }
        },
        {
          "rank": 238,
          "movement": -2,
          "points": 326,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:763112",
            "name": "Struplova, Julie",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "STR"
          }
        },
        {
          "rank": 239,
          "movement": -2,
          "points": 324,
          "competitions_played": 3,
          "competitor": {
            "id": "sr:competitor:55401",
            "name": "Jabeur, Ons",
            "country": "Tunisia",
            "country_code": "TUN",
            "abbreviation": "JAB"
          }
        },
        {
          "rank": 240,
          "movement": -2,
          "points": 322,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:43527",
            "name": "Kumkhum, Luksika",
            "country": "Thailand",
            "country_code": "THA",
            "abbreviation": "KUM"
          }
        },
        {
          "rank": 241,
          "movement": -6,
          "points": 320,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:448613",
            "name": "Falkner, Ziva",
            "country": "Slovenia",
            "country_code": "SVN",
            "abbreviation": "FAL"
          }
        },
        {
          "rank": 242,
          "movement": 2,
          "points": 320,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:445209",
            "name": "Xiao, Zhenghua",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "XIA"
          }
        },
        {
          "rank": 243,
          "movement": -4,
          "points": 316,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:152106",
            "name": "Zaar, Lisa",
            "country": "Sweden",
            "country_code": "SWE",
            "abbreviation": "ZAA"
          }
        },
        {
          "rank": 244,
          "movement": -4,
          "points": 316,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:73500",
            "name": "Loeb, Jamie",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "LOE"
          }
        },
        {
          "rank": 245,
          "movement": -3,
          "points": 316,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:341216",
            "name": "Charaeva, Alina",
            "country": "Neutral",
            "abbreviation": "CHA"
          }
        },
        {
          "rank": 246,
          "movement": -3,
          "points": 312,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:59213",
            "name": "Perez Garcia, Maria Paulina",
            "country": "Colombia",
            "country_code": "COL",
            "abbreviation": "PER"
          }
        },
        {
          "rank": 247,
          "movement": -2,
          "points": 307,
          "competitions_played": 6,
          "competitor": {
            "id": "sr:competitor:172590",
            "name": "Burrage, Jodie",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "BUR"
          }
        },
        {
          "rank": 248,
          "movement": -1,
          "points": 306,
          "competitions_played": 34,
          "competitor": {
            "id": "sr:competitor:233478",
            "name": "Bayerlova, Michaela",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "BAY"
          }
        },
        {
          "rank": 249,
          "movement": -8,
          "points": 304,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:181062",
            "name": "Kung, Leonie",
            "country": "Switzerland",
            "country_code": "CHE",
            "abbreviation": "KUN"
          }
        },
        {
          "rank": 250,
          "movement": -2,
          "points": 303,
          "competitions_played": 33,
          "competitor": {
            "id": "sr:competitor:47985",
            "name": "Marcinkevica, Diana",
            "country": "Latvia",
            "country_code": "LVA",
            "abbreviation": "MAR"
          }
        },
        {
          "rank": 251,
          "movement": -1,
          "points": 303,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:517274",
            "name": "Rajecki, Amelia",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "RAJ"
          }
        },
        {
          "rank": 252,
          "movement": -3,
          "points": 301,
          "competitions_played": 9,
          "competitor": {
            "id": "sr:competitor:141892",
            "name": "Carle, Maria",
            "country": "Argentina",
            "country_code": "ARG",
            "abbreviation": "CAR"
          }
        },
        {
          "rank": 253,
          "movement": -2,
          "points": 299,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:60028",
            "name": "Zeballos Melgar, Noelia",
            "country": "Bolivia",
            "country_code": "BOL",
            "abbreviation": "ZEM"
          }
        },
        {
          "rank": 254,
          "movement": -2,
          "points": 299,
          "competitions_played": 24,
          "competitor": {
            "id": "sr:competitor:731441",
            "name": "Vargova, Nina",
            "country": "Slovakia",
            "country_code": "SVK",
            "abbreviation": "VAR"
          }
        },
        {
          "rank": 255,
          "movement": -2,
          "points": 297,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:194690",
            "name": "Mateas, Maria",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "MAT"
          }
        },
        {
          "rank": 256,
          "movement": -2,
          "points": 297,
          "competitions_played": 24,
          "competitor": {
            "id": "sr:competitor:46650",
            "name": "Kolb, Nadia",
            "country": "Ukraine",
            "country_code": "UKR",
            "abbreviation": "KOL"
          }
        },
        {
          "rank": 257,
          "movement": 6,
          "points": 296,
          "competitions_played": 24,
          "competitor": {
            "id": "sr:competitor:807358",
            "name": "Rakotomanga Rajaonah, Tiantsoa Sarah",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "RAK"
          }
        },
        {
          "rank": 258,
          "movement": -3,
          "points": 293,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:499098",
            "name": "Ito, Aoi",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "ITO"
          }
        },
        {
          "rank": 259,
          "movement": -2,
          "points": 293,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:222546",
            "name": "Kuzmova, Katarina",
            "country": "Slovakia",
            "country_code": "SVK",
            "abbreviation": "KUZ"
          }
        },
        {
          "rank": 260,
          "movement": -2,
          "points": 292,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:282597",
            "name": "Park, Sohyun",
            "country": "Republic of Korea",
            "country_code": "KOR",
            "abbreviation": "PAR"
          }
        },
        {
          "rank": 261,
          "movement": -2,
          "points": 292,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:70822",
            "name": "Morisaki, Kanako",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "MOR"
          }
        },
        {
          "rank": 262,
          "movement": -2,
          "points": 291,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:343066",
            "name": "Hosogi, Sakura",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "HOS"
          }
        },
        {
          "rank": 263,
          "movement": 4,
          "points": 289,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:355958",
            "name": "Visscher, Stephanie Judith",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "VIS"
          }
        },
        {
          "rank": 264,
          "movement": -3,
          "points": 287,
          "competitions_played": 8,
          "competitor": {
            "id": "sr:competitor:202363",
            "name": "Sun, Lulu",
            "country": "New Zealand",
            "country_code": "NZL",
            "abbreviation": "SUN"
          }
        },
        {
          "rank": 265,
          "movement": -3,
          "points": 286,
          "competitions_played": 29,
          "competitor": {
            "id": "sr:competitor:409673",
            "name": "Zelnickova, Radka",
            "country": "Slovakia",
            "country_code": "SVK",
            "abbreviation": "ZEL"
          }
        },
        {
          "rank": 266,
          "movement": 17,
          "points": 283,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:265553",
            "name": "Naito, Yuki",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "NAI"
          }
        },
        {
          "rank": 267,
          "movement": -3,
          "points": 282,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:41374",
            "name": "Tomova, Viktoriya",
            "country": "Bulgaria",
            "country_code": "BGR",
            "abbreviation": "TOM"
          }
        },
        {
          "rank": 268,
          "movement": -12,
          "points": 282,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:812502",
            "name": "Xu, Mingge",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "MIN"
          }
        },
        {
          "rank": 269,
          "movement": -4,
          "points": 278,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:673491",
            "name": "Szabo, Briana",
            "country": "Romania",
            "country_code": "ROU",
            "abbreviation": "SZA"
          }
        },
        {
          "rank": 270,
          "movement": -4,
          "points": 275,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:731427",
            "name": "Micic, Elena",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "MIC"
          }
        },
        {
          "rank": 271,
          "movement": 7,
          "points": 273,
          "competitions_played": 24,
          "competitor": {
            "id": "sr:competitor:282057",
            "name": "Guo, Meiqi",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "GUO"
          }
        },
        {
          "rank": 272,
          "movement": -4,
          "points": 272,
          "competitions_played": 4,
          "competitor": {
            "id": "sr:competitor:845268",
            "name": "Korneeva, Alina",
            "country": "Neutral",
            "abbreviation": "KOR"
          }
        },
        {
          "rank": 273,
          "movement": -2,
          "points": 271,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:67194",
            "name": "Kolb, Maryna",
            "country": "Ukraine",
            "country_code": "UKR",
            "abbreviation": "KOL"
          }
        },
        {
          "rank": 274,
          "movement": -2,
          "points": 271,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:234398",
            "name": "Nahimana, Sada",
            "country": "Burundi",
            "country_code": "BDI",
            "abbreviation": "NAH"
          }
        },
        {
          "rank": 275,
          "movement": -2,
          "points": 268,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:292540",
            "name": "Matsuda, Misaki",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "MAT"
          }
        },
        {
          "rank": 276,
          "movement": -2,
          "points": 268,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:86894",
            "name": "Shinde, Vasanti",
            "country": "India",
            "country_code": "IND",
            "abbreviation": "SHI"
          }
        },
        {
          "rank": 277,
          "movement": -2,
          "points": 267,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:283489",
            "name": "Imamura, Saki",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "IMA"
          }
        },
        {
          "rank": 278,
          "movement": -2,
          "points": 266,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:343294",
            "name": "Kubanova, Karolina",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "KUB"
          }
        },
        {
          "rank": 279,
          "movement": -2,
          "points": 266,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:868599",
            "name": "McDonald, Ella",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "MCD"
          }
        },
        {
          "rank": 280,
          "movement": -1,
          "points": 265,
          "competitions_played": 5,
          "competitor": {
            "id": "sr:competitor:1017327",
            "name": "Samson, Laura",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "SAM"
          }
        },
        {
          "rank": 281,
          "movement": -1,
          "points": 265,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:136372",
            "name": "Parnaby, Alana",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "PAR"
          }
        },
        {
          "rank": 282,
          "movement": -1,
          "points": 264,
          "competitions_played": 7,
          "competitor": {
            "id": "sr:competitor:755469",
            "name": "Todoni, Anca Alexia",
            "country": "Romania",
            "country_code": "ROU",
            "abbreviation": "TOD"
          }
        },
        {
          "rank": 284,
          "movement": 0,
          "points": 262,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:223862",
            "name": "Laboutkova, Aneta",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "LAB"
          }
        },
        {
          "rank": 285,
          "movement": 27,
          "points": 262,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:870981",
            "name": "Li, Yu-Yun",
            "country": "Chinese Taipei",
            "country_code": "TPE",
            "abbreviation": "YU-"
          }
        },
        {
          "rank": 286,
          "movement": 0,
          "points": 260,
          "competitions_played": 3,
          "competitor": {
            "id": "sr:competitor:62924",
            "name": "Boulter, Katie",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "BOU"
          }
        },
        {
          "rank": 287,
          "movement": 0,
          "points": 258,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:51315",
            "name": "Anderson, Robin",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "AND"
          }
        },
        {
          "rank": 288,
          "movement": 0,
          "points": 258,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:289093",
            "name": "Belgraver, Julie",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "BEL"
          }
        },
        {
          "rank": 289,
          "movement": 1,
          "points": 257,
          "competitions_played": 3,
          "competitor": {
            "id": "sr:competitor:75825",
            "name": "Bektas, Emina",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "BEK"
          }
        },
        {
          "rank": 290,
          "movement": 1,
          "points": 257,
          "competitions_played": 32,
          "competitor": {
            "id": "sr:competitor:315663",
            "name": "Barry, Monique",
            "country": "New Zealand",
            "country_code": "NZL",
            "abbreviation": "BAR"
          }
        },
        {
          "rank": 291,
          "movement": 1,
          "points": 257,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:198498",
            "name": "Hutchinson, Holly",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "HUT"
          }
        },
        {
          "rank": 292,
          "movement": 1,
          "points": 256,
          "competitions_played": 24,
          "competitor": {
            "id": "sr:competitor:70970",
            "name": "Bhatia, Riya",
            "country": "India",
            "country_code": "IND",
            "abbreviation": "BHA"
          }
        },
        {
          "rank": 293,
          "movement": 1,
          "points": 256,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:142942",
            "name": "Bozovic, Alexandra",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "BOZ"
          }
        },
        {
          "rank": 294,
          "movement": 1,
          "points": 255,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:278943",
            "name": "Lansere, Sofya",
            "country": "Neutral",
            "abbreviation": "LAN"
          }
        },
        {
          "rank": 295,
          "movement": 1,
          "points": 255,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:395740",
            "name": "Bhamidipaty, Shrivalli Rashmikaa",
            "country": "India",
            "country_code": "IND",
            "abbreviation": "BHA"
          }
        },
        {
          "rank": 296,
          "movement": 1,
          "points": 255,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:48486",
            "name": "Gorgodze, Ekaterine",
            "country": "Georgia",
            "country_code": "GEO",
            "abbreviation": "GOR"
          }
        },
        {
          "rank": 297,
          "movement": 1,
          "points": 247,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:337813",
            "name": "Riera, Julia",
            "country": "Argentina",
            "country_code": "ARG",
            "abbreviation": "RIE"
          }
        },
        {
          "rank": 298,
          "movement": 1,
          "points": 246,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:896765",
            "name": "Ishii, Sayaka",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "ISH"
          }
        },
        {
          "rank": 299,
          "movement": 1,
          "points": 246,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:104929",
            "name": "Tona, Miriana",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "TON"
          }
        },
        {
          "rank": 300,
          "movement": 1,
          "points": 245,
          "competitions_played": 7,
          "competitor": {
            "id": "sr:competitor:99405",
            "name": "Inglis, Maddison",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "ING"
          }
        },
        {
          "rank": 301,
          "movement": -32,
          "points": 245,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:132412",
            "name": "Fita Boluda, Angela",
            "country": "Spain",
            "country_code": "ESP",
            "abbreviation": "FIT"
          }
        },
        {
          "rank": 302,
          "movement": 0,
          "points": 242,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:54397",
            "name": "Tig, Patricia Maria",
            "country": "Romania",
            "country_code": "ROU",
            "abbreviation": "TIG"
          }
        },
        {
          "rank": 303,
          "movement": 0,
          "points": 242,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:510530",
            "name": "Abe, Hiromi",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "ABE"
          }
        },
        {
          "rank": 304,
          "movement": 0,
          "points": 242,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:213144",
            "name": "Lemaitre, Tiphanie",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "LEM"
          }
        },
        {
          "rank": 305,
          "movement": -20,
          "points": 241,
          "competitions_played": 8,
          "competitor": {
            "id": "sr:competitor:534045",
            "name": "Gibson, Talia",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "GIB"
          }
        },
        {
          "rank": 306,
          "movement": -1,
          "points": 240,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:447703",
            "name": "Sato, Hikaru",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "SAT"
          }
        },
        {
          "rank": 307,
          "movement": 0,
          "points": 237,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:627278",
            "name": "Eala, Alexandra",
            "country": "Philippines",
            "country_code": "PHL",
            "abbreviation": "EAL"
          }
        },
        {
          "rank": 308,
          "movement": 0,
          "points": 236,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:194572",
            "name": "Dartron, Emeline",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "DAR"
          }
        },
        {
          "rank": 309,
          "movement": 0,
          "points": 236,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:145930",
            "name": "Hayashi, Erina",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "HAY"
          }
        },
        {
          "rank": 310,
          "movement": 0,
          "points": 235,
          "competitions_played": 9,
          "competitor": {
            "id": "sr:competitor:319349",
            "name": "Rouvroy, Margaux",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "ROU"
          }
        },
        {
          "rank": 311,
          "movement": 6,
          "points": 235,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:801396",
            "name": "Gureva, Anastasiia",
            "country": "Neutral",
            "abbreviation": "GUR"
          }
        },
        {
          "rank": 312,
          "movement": -1,
          "points": 235,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:567285",
            "name": "Hietaranta, Laura",
            "country": "Finland",
            "country_code": "FIN",
            "abbreviation": "HIE"
          }
        },
        {
          "rank": 313,
          "movement": -7,
          "points": 235,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:122668",
            "name": "Daniel, Jaeda",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "DAN"
          }
        },
        {
          "rank": 314,
          "movement": 30,
          "points": 234,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:233266",
            "name": "Ovcharenko, Ekaterina",
            "country": "Neutral",
            "abbreviation": "OVC"
          }
        },
        {
          "rank": 315,
          "movement": -2,
          "points": 232,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:106341",
            "name": "Knutson, Gabriela",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "KNU"
          }
        },
        {
          "rank": 316,
          "movement": -2,
          "points": 232,
          "competitions_played": 24,
          "competitor": {
            "id": "sr:competitor:154806",
            "name": "Laskutova, Ksenia",
            "country": "Russia",
            "country_code": "RUS",
            "abbreviation": "LAS"
          }
        },
        {
          "rank": 317,
          "movement": -2,
          "points": 229,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:120664",
            "name": "Pedretti, Thaisa Grana",
            "country": "Brazil",
            "country_code": "BRA",
            "abbreviation": "PED"
          }
        },
        {
          "rank": 318,
          "movement": -2,
          "points": 228,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:337811",
            "name": "Ortenzi, Jazmin",
            "country": "Argentina",
            "country_code": "ARG",
            "abbreviation": "ORT"
          }
        },
        {
          "rank": 319,
          "movement": 0,
          "points": 227,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:45900",
            "name": "Marozava, Lidziya",
            "country": "Neutral",
            "abbreviation": "MAR"
          }
        },
        {
          "rank": 320,
          "movement": 0,
          "points": 227,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:285629",
            "name": "Hindova, Denisa",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "HIN"
          }
        },
        {
          "rank": 321,
          "movement": 0,
          "points": 227,
          "competitions_played": 25,
          "competitor": {
            "id": "sr:competitor:810694",
            "name": "Okuwaki, Rinon",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "OKU"
          }
        },
        {
          "rank": 322,
          "movement": 42,
          "points": 224,
          "competitions_played": 7,
          "competitor": {
            "id": "sr:competitor:47948",
            "name": "Rosolska, Alicja",
            "country": "Poland",
            "country_code": "POL",
            "abbreviation": "ROS"
          }
        },
        {
          "rank": 323,
          "movement": 0,
          "points": 224,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:37638",
            "name": "Sema, Erika",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "SEM"
          }
        },
        {
          "rank": 324,
          "movement": 0,
          "points": 224,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:63238",
            "name": "Morderger, Yana",
            "country": "Germany",
            "country_code": "DEU",
            "abbreviation": "MOR"
          }
        },
        {
          "rank": 325,
          "movement": 0,
          "points": 223,
          "competitions_played": 9,
          "competitor": {
            "id": "sr:competitor:165866",
            "name": "Miyazaki, Yuriko Lily",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "MIY"
          }
        },
        {
          "rank": 326,
          "movement": 0,
          "points": 223,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:63220",
            "name": "Ponchet, Jessika",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "PON"
          }
        },
        {
          "rank": 327,
          "movement": 0,
          "points": 223,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:61922",
            "name": "Drazic, Mariana",
            "country": "Croatia",
            "country_code": "HRV",
            "abbreviation": "DRA"
          }
        },
        {
          "rank": 328,
          "movement": 0,
          "points": 222,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:49963",
            "name": "Omae, Akiko",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "OMA"
          }
        },
        {
          "rank": 329,
          "movement": 0,
          "points": 221,
          "competitions_played": 6,
          "competitor": {
            "id": "sr:competitor:728549",
            "name": "Valentova, Tereza",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "VAL"
          }
        },
        {
          "rank": 330,
          "movement": 30,
          "points": 221,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:329009",
            "name": "Ryser, Valentina",
            "country": "Switzerland",
            "country_code": "CHE",
            "abbreviation": "RYS"
          }
        },
        {
          "rank": 331,
          "movement": -1,
          "points": 220,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:345134",
            "name": "Lee, Ya-Hsin",
            "country": "Chinese Taipei",
            "country_code": "TPE",
            "abbreviation": "LEE"
          }
        },
        {
          "rank": 332,
          "movement": -1,
          "points": 219,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:936009",
            "name": "van Emst, Sarah",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "VAN"
          }
        },
        {
          "rank": 333,
          "movement": -1,
          "points": 219,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:25822",
            "name": "Shapatava, Sofia",
            "country": "Georgia",
            "country_code": "GEO",
            "abbreviation": "SHA"
          }
        },
        {
          "rank": 334,
          "movement": 0,
          "points": 214,
          "competitions_played": 9,
          "competitor": {
            "id": "sr:competitor:87078",
            "name": "Hourigan, Paige Mary",
            "country": "New Zealand",
            "country_code": "NZL",
            "abbreviation": "HOU"
          }
        },
        {
          "rank": 335,
          "movement": 0,
          "points": 214,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:849533",
            "name": "Lin, Fang An",
            "country": "Chinese Taipei",
            "country_code": "TPE",
            "abbreviation": "LIN"
          }
        },
        {
          "rank": 336,
          "movement": 0,
          "points": 213,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:209716",
            "name": "Mansouri, Yasmine",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "MAN"
          }
        },
        {
          "rank": 337,
          "movement": 0,
          "points": 212,
          "competitions_played": 27,
          "competitor": {
            "id": "sr:competitor:153744",
            "name": "Pereira, Rebeca",
            "country": "Brazil",
            "country_code": "BRA",
            "abbreviation": "PER"
          }
        },
        {
          "rank": 338,
          "movement": -16,
          "points": 212,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:586739",
            "name": "Ambrosio, Silvia",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "AMB"
          }
        },
        {
          "rank": 339,
          "movement": -1,
          "points": 212,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:513582",
            "name": "Chaudhari, Vaidehi",
            "country": "India",
            "country_code": "IND",
            "abbreviation": "CHA"
          }
        },
        {
          "rank": 340,
          "movement": -1,
          "points": 211,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:406199",
            "name": "Jacquemot, Elsa",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "JAC"
          }
        },
        {
          "rank": 341,
          "movement": -1,
          "points": 211,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:254553",
            "name": "Nagy, Adrienn",
            "country": "Hungary",
            "country_code": "HUN",
            "abbreviation": "NAG"
          }
        },
        {
          "rank": 342,
          "movement": 38,
          "points": 211,
          "competitions_played": 29,
          "competitor": {
            "id": "sr:competitor:20158",
            "name": "Webley-Smith, Emily",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "WEB"
          }
        },
        {
          "rank": 343,
          "movement": -2,
          "points": 210,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:380368",
            "name": "Sebestova, Ivana",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "SEB"
          }
        },
        {
          "rank": 344,
          "movement": -2,
          "points": 209,
          "competitions_played": 6,
          "competitor": {
            "id": "sr:competitor:137962",
            "name": "Day, Kayla",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "DAY"
          }
        },
        {
          "rank": 345,
          "movement": -2,
          "points": 209,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:1020177",
            "name": "Huang, Yujia",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "HUA"
          }
        },
        {
          "rank": 346,
          "movement": -1,
          "points": 207,
          "competitions_played": 4,
          "competitor": {
            "id": "sr:competitor:225130",
            "name": "Starodubtseva, Yuliia",
            "country": "Ukraine",
            "country_code": "UKR",
            "abbreviation": "STA"
          }
        },
        {
          "rank": 347,
          "movement": -14,
          "points": 206,
          "competitions_played": 6,
          "competitor": {
            "id": "sr:competitor:210716",
            "name": "Lamens, Suzan",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "LAM"
          }
        },
        {
          "rank": 348,
          "movement": -2,
          "points": 206,
          "competitions_played": 28,
          "competitor": {
            "id": "sr:competitor:201105",
            "name": "Yuan, Chengyiyi",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "YUA"
          }
        },
        {
          "rank": 349,
          "movement": -2,
          "points": 205,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:467037",
            "name": "Kudermetova, Polina",
            "country": "Neutral",
            "abbreviation": "KUD"
          }
        },
        {
          "rank": 350,
          "movement": -2,
          "points": 205,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:119496",
            "name": "McPhee, Kaylah",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "MCP"
          }
        },
        {
          "rank": 351,
          "movement": 17,
          "points": 204,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:330689",
            "name": "Kovapitukted, Punnin",
            "country": "Thailand",
            "country_code": "THA",
            "abbreviation": "KOV"
          }
        },
        {
          "rank": 352,
          "movement": -3,
          "points": 202,
          "competitions_played": 2,
          "competitor": {
            "id": "sr:competitor:341112",
            "name": "Zakharova, Anastasia",
            "country": "Neutral",
            "abbreviation": "ZAK"
          }
        },
        {
          "rank": 353,
          "movement": 37,
          "points": 201,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:262023",
            "name": "Wang, Meiling",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "WAN"
          }
        },
        {
          "rank": 354,
          "movement": -4,
          "points": 201,
          "competitions_played": 5,
          "competitor": {
            "id": "sr:competitor:153736",
            "name": "Glushko, Lina",
            "country": "Israel",
            "country_code": "ISR",
            "abbreviation": "GLU"
          }
        },
        {
          "rank": 355,
          "movement": -4,
          "points": 201,
          "competitions_played": 24,
          "competitor": {
            "id": "sr:competitor:435794",
            "name": "Zolotareva, Anastasia",
            "country": "Neutral",
            "abbreviation": "ZOL"
          }
        },
        {
          "rank": 356,
          "movement": -4,
          "points": 200,
          "competitions_played": 25,
          "competitor": {
            "id": "sr:competitor:152762",
            "name": "Kuczer, Daria",
            "country": "Poland",
            "country_code": "POL",
            "abbreviation": "KUC"
          }
        },
        {
          "rank": 357,
          "movement": 53,
          "points": 199,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:842594",
            "name": "Li, Zongyu",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "ZON"
          }
        },
        {
          "rank": 358,
          "movement": -5,
          "points": 198,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:164852",
            "name": "Okalova, Martina",
            "country": "Slovakia",
            "country_code": "SVK",
            "abbreviation": "OKA"
          }
        },
        {
          "rank": 359,
          "movement": 46,
          "points": 198,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:129534",
            "name": "Hruncakova, Viktoria",
            "country": "Slovakia",
            "country_code": "SVK",
            "abbreviation": "HRU"
          }
        },
        {
          "rank": 360,
          "movement": -6,
          "points": 198,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:750327",
            "name": "Iatcenko, Polina",
            "country": "Neutral",
            "abbreviation": "IAT"
          }
        },
        {
          "rank": 361,
          "movement": -6,
          "points": 197,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:813490",
            "name": "Hobgarski, Katharina",
            "country": "Germany",
            "country_code": "DEU",
            "abbreviation": "HOB"
          }
        },
        {
          "rank": 362,
          "movement": 7,
          "points": 196,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:403329",
            "name": "Toth, Amarissa Kiara",
            "country": "Hungary",
            "country_code": "HUN",
            "abbreviation": "TOT"
          }
        },
        {
          "rank": 363,
          "movement": -45,
          "points": 196,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:202795",
            "name": "Vismane, Daniela",
            "country": "Latvia",
            "country_code": "LVA",
            "abbreviation": "VIS"
          }
        },
        {
          "rank": 364,
          "movement": -7,
          "points": 194,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:720625",
            "name": "Radivojevic, Lola",
            "country": "Serbia",
            "country_code": "SRB",
            "abbreviation": "RAD"
          }
        },
        {
          "rank": 365,
          "movement": -7,
          "points": 194,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:226092",
            "name": "Shimizu, Eri",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "SHI"
          }
        },
        {
          "rank": 366,
          "movement": -10,
          "points": 194,
          "competitions_played": 25,
          "competitor": {
            "id": "sr:competitor:158636",
            "name": "Prisacariu, Andreea",
            "country": "Romania",
            "country_code": "ROU",
            "abbreviation": "PRI"
          }
        },
        {
          "rank": 367,
          "movement": -6,
          "points": 192,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:624838",
            "name": "Shi, Han",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "SHI"
          }
        },
        {
          "rank": 368,
          "movement": -6,
          "points": 192,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:745799",
            "name": "Urgesi, Federica",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "URG"
          }
        },
        {
          "rank": 369,
          "movement": -6,
          "points": 192,
          "competitions_played": 23,
          "competitor": {
            "id": "sr:competitor:54983",
            "name": "Morderger, Tayisiya",
            "country": "Germany",
            "country_code": "DEU",
            "abbreviation": "MOR"
          }
        },
        {
          "rank": 370,
          "movement": -5,
          "points": 191,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:496378",
            "name": "Yamazaki, Ikumi",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "YAM"
          }
        },
        {
          "rank": 371,
          "movement": -4,
          "points": 190,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:153748",
            "name": "Jones, Makenna",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "JON"
          }
        },
        {
          "rank": 372,
          "movement": -1,
          "points": 186,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:42864",
            "name": "Lizarazo, Yuliana",
            "country": "Colombia",
            "country_code": "COL",
            "abbreviation": "LIZ"
          }
        },
        {
          "rank": 373,
          "movement": -1,
          "points": 186,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:843378",
            "name": "Perez Alarcon, Lucciana",
            "country": "Peru",
            "country_code": "PER",
            "abbreviation": "PER"
          }
        },
        {
          "rank": 374,
          "movement": -1,
          "points": 186,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:246945",
            "name": "Da Silva Fick, Gabriella",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "DA"
          }
        },
        {
          "rank": 375,
          "movement": -1,
          "points": 186,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:105063",
            "name": "Gavrila, Oana",
            "country": "Romania",
            "country_code": "ROU",
            "abbreviation": "GAV"
          }
        },
        {
          "rank": 376,
          "movement": -1,
          "points": 185,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:213140",
            "name": "Lene, Emma",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "LEN"
          }
        },
        {
          "rank": 377,
          "movement": -1,
          "points": 185,
          "competitions_played": 24,
          "competitor": {
            "id": "sr:competitor:750329",
            "name": "Candiotto, Ana",
            "country": "Brazil",
            "country_code": "BRA",
            "abbreviation": "CAN"
          }
        },
        {
          "rank": 378,
          "movement": -1,
          "points": 185,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:282219",
            "name": "Sakatsume, Himeno",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "SAK"
          }
        },
        {
          "rank": 379,
          "movement": 22,
          "points": 185,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:299258",
            "name": "Bartone, Kamilla",
            "country": "Latvia",
            "country_code": "LVA",
            "abbreviation": "BAR"
          }
        },
        {
          "rank": 380,
          "movement": -2,
          "points": 184,
          "competitions_played": 2,
          "competitor": {
            "id": "sr:competitor:42459",
            "name": "Rogers, Shelby",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "ROG"
          }
        },
        {
          "rank": 381,
          "movement": -2,
          "points": 184,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:47876",
            "name": "Shinikova, Isabella",
            "country": "Bulgaria",
            "country_code": "BGR",
            "abbreviation": "SHI"
          }
        },
        {
          "rank": 382,
          "movement": -16,
          "points": 184,
          "competitions_played": 25,
          "competitor": {
            "id": "sr:competitor:99775",
            "name": "Saigo, Yukina",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "SAI"
          }
        },
        {
          "rank": 383,
          "movement": -2,
          "points": 183,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:280989",
            "name": "Kawamura, Mana",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "KAW"
          }
        },
        {
          "rank": 384,
          "movement": -2,
          "points": 181,
          "competitions_played": 5,
          "competitor": {
            "id": "sr:competitor:245295",
            "name": "Waltert, Simona",
            "country": "Switzerland",
            "country_code": "CHE",
            "abbreviation": "WAL"
          }
        },
        {
          "rank": 385,
          "movement": -2,
          "points": 181,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:436690",
            "name": "Tkacheva, Mariia",
            "country": "Neutral",
            "abbreviation": "TKA"
          }
        },
        {
          "rank": 386,
          "movement": -2,
          "points": 179,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:348196",
            "name": "Amariei, Ilinca Dalina",
            "country": "Romania",
            "country_code": "ROU",
            "abbreviation": "AMA"
          }
        },
        {
          "rank": 387,
          "movement": -2,
          "points": 179,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:751899",
            "name": "Brace, Cadence",
            "country": "Canada",
            "country_code": "CAN",
            "abbreviation": "BRA"
          }
        },
        {
          "rank": 388,
          "movement": -2,
          "points": 177,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:960043",
            "name": "Zolotareva, Rada",
            "country": "Neutral",
            "abbreviation": "ZOL"
          }
        },
        {
          "rank": 389,
          "movement": 4,
          "points": 177,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:66516",
            "name": "Ayukawa, Mana",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "AYU"
          }
        },
        {
          "rank": 390,
          "movement": 14,
          "points": 176,
          "competitions_played": 5,
          "competitor": {
            "id": "sr:competitor:18588",
            "name": "Safarova, Lucie",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "SAF"
          }
        },
        {
          "rank": 391,
          "movement": -2,
          "points": 174,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:280635",
            "name": "Schmidt, Antonia",
            "country": "Germany",
            "country_code": "DEU",
            "abbreviation": "SCH"
          }
        },
        {
          "rank": 392,
          "movement": -1,
          "points": 172,
          "competitions_played": 6,
          "competitor": {
            "id": "sr:competitor:110803",
            "name": "Minnen, Greet",
            "country": "Belgium",
            "country_code": "BEL",
            "abbreviation": "MIN"
          }
        },
        {
          "rank": 393,
          "movement": -6,
          "points": 172,
          "competitions_played": 30,
          "competitor": {
            "id": "sr:competitor:59662",
            "name": "Sanchez, Ana Sofia",
            "country": "Mexico",
            "country_code": "MEX",
            "abbreviation": "SAN"
          }
        },
        {
          "rank": 394,
          "movement": 3,
          "points": 172,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:130624",
            "name": "Gasanova, Anastasia",
            "country": "Neutral",
            "abbreviation": "GAS"
          }
        },
        {
          "rank": 395,
          "movement": -1,
          "points": 171,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:202623",
            "name": "Zavatska, Katarina",
            "country": "Ukraine",
            "country_code": "UKR",
            "abbreviation": "ZAV"
          }
        },
        {
          "rank": 396,
          "movement": -1,
          "points": 171,
          "competitions_played": 4,
          "competitor": {
            "id": "sr:competitor:48455",
            "name": "Golubic, Viktorija",
            "country": "Switzerland",
            "country_code": "CHE",
            "abbreviation": "GOL"
          }
        },
        {
          "rank": 397,
          "movement": -9,
          "points": 171,
          "competitions_played": 29,
          "competitor": {
            "id": "sr:competitor:78785",
            "name": "Rodriguez, Victoria",
            "country": "Mexico",
            "country_code": "MEX",
            "abbreviation": "ROD"
          }
        },
        {
          "rank": 398,
          "movement": 201,
          "points": 170,
          "competitions_played": 6,
          "competitor": {
            "id": "sr:competitor:54171",
            "name": "Benoit, Marie",
            "country": "Belgium",
            "country_code": "BEL",
            "abbreviation": "BEN"
          }
        },
        {
          "rank": 399,
          "movement": -1,
          "points": 170,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:1020859",
            "name": "Pawlikowska,  Zuzanna",
            "country": "Poland",
            "country_code": "POL",
            "abbreviation": "PAW"
          }
        },
        {
          "rank": 400,
          "movement": -1,
          "points": 169,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:58053",
            "name": "Sharma, Astra",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "SHA"
          }
        },
        {
          "rank": 401,
          "movement": -1,
          "points": 169,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:138654",
            "name": "Duerst, Jenny",
            "country": "Switzerland",
            "country_code": "CHE",
            "abbreviation": "DUE"
          }
        },
        {
          "rank": 402,
          "movement": 0,
          "points": 168,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:206957",
            "name": "Nagata, Anri",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "NAG"
          }
        },
        {
          "rank": 403,
          "movement": 3,
          "points": 166,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:103375",
            "name": "Serban, Raluca Georgiana",
            "country": "Cyprus",
            "country_code": "CYP",
            "abbreviation": "SER"
          }
        },
        {
          "rank": 404,
          "movement": -34,
          "points": 166,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:46273",
            "name": "Dinu, Cristina",
            "country": "Romania",
            "country_code": "ROU",
            "abbreviation": "DIN"
          }
        },
        {
          "rank": 405,
          "movement": 3,
          "points": 166,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:72634",
            "name": "Ozeki, Michika",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "OZE"
          }
        },
        {
          "rank": 406,
          "movement": 5,
          "points": 165,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:565020",
            "name": "Maklakova, Ekaterina",
            "country": "Neutral",
            "abbreviation": "MAK"
          }
        },
        {
          "rank": 407,
          "movement": 5,
          "points": 164,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:171354",
            "name": "Romero, Camila",
            "country": "Ecuador",
            "country_code": "ECU",
            "abbreviation": "ROM"
          }
        },
        {
          "rank": 408,
          "movement": 5,
          "points": 163,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:741607",
            "name": "Simunyu, Celine",
            "country": "Ireland",
            "country_code": "IRL",
            "abbreviation": "SIM"
          }
        },
        {
          "rank": 409,
          "movement": 5,
          "points": 162,
          "competitions_played": 6,
          "competitor": {
            "id": "sr:competitor:264117",
            "name": "Bolton, Elysia",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "BOL"
          }
        },
        {
          "rank": 410,
          "movement": -51,
          "points": 162,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:217036",
            "name": "Malygina, Elena",
            "country": "Estonia",
            "country_code": "EST",
            "abbreviation": "MAL"
          }
        },
        {
          "rank": 411,
          "movement": -15,
          "points": 161,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:588449",
            "name": "Laskevich, Evialina",
            "country": "Neutral",
            "abbreviation": "LAS"
          }
        },
        {
          "rank": 412,
          "movement": 16,
          "points": 161,
          "competitions_played": 20,
          "competitor": {
            "id": "sr:competitor:98105",
            "name": "Matoula, Martha",
            "country": "Greece",
            "country_code": "GRC",
            "abbreviation": "MAT"
          }
        },
        {
          "rank": 413,
          "movement": 2,
          "points": 160,
          "competitions_played": 4,
          "competitor": {
            "id": "sr:competitor:366114",
            "name": "Avanesyan, Elina",
            "country": "Armenia",
            "country_code": "ARM",
            "abbreviation": "AVA"
          }
        },
        {
          "rank": 414,
          "movement": -11,
          "points": 160,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:283483",
            "name": "Kozaki, Funa",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "KOZ"
          }
        },
        {
          "rank": 415,
          "movement": 1,
          "points": 160,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:782216",
            "name": "Drugdova, Salma",
            "country": "Slovakia",
            "country_code": "SVK",
            "abbreviation": "DRU"
          }
        },
        {
          "rank": 416,
          "movement": 13,
          "points": 159,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:107327",
            "name": "In-Albon, Ylena",
            "country": "Switzerland",
            "country_code": "CHE",
            "abbreviation": "IN-"
          }
        },
        {
          "rank": 417,
          "movement": 0,
          "points": 159,
          "competitions_played": 25,
          "competitor": {
            "id": "sr:competitor:80723",
            "name": "Herazo Gonzalez, Maria Fernanda",
            "country": "Colombia",
            "country_code": "COL",
            "abbreviation": "HER"
          }
        },
        {
          "rank": 418,
          "movement": 0,
          "points": 159,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:98523",
            "name": "Ye, Qiu Yu",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "QIU"
          }
        },
        {
          "rank": 419,
          "movement": 0,
          "points": 159,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:389048",
            "name": "Weckerle, Marie",
            "country": "Luxembourg",
            "country_code": "LUX",
            "abbreviation": "WEC"
          }
        },
        {
          "rank": 420,
          "movement": 0,
          "points": 157,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:64606",
            "name": "Cabaj Awad, Jacqueline",
            "country": "Sweden",
            "country_code": "SWE",
            "abbreviation": "CAB"
          }
        },
        {
          "rank": 421,
          "movement": -29,
          "points": 157,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:182056",
            "name": "Robbe, Alice",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "ROB"
          }
        },
        {
          "rank": 422,
          "movement": -1,
          "points": 156,
          "competitions_played": 5,
          "competitor": {
            "id": "sr:competitor:45584",
            "name": "Zhu, Lin",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "ZHU"
          }
        },
        {
          "rank": 423,
          "movement": -1,
          "points": 156,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:132988",
            "name": "MA, Yexin",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "YEX"
          }
        },
        {
          "rank": 424,
          "movement": 0,
          "points": 155,
          "competitions_played": 3,
          "competitor": {
            "id": "sr:competitor:19876",
            "name": "Wickmayer, Yanina",
            "country": "Belgium",
            "country_code": "BEL",
            "abbreviation": "WIC"
          }
        },
        {
          "rank": 425,
          "movement": 0,
          "points": 155,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:873729",
            "name": "Bojica, Stefania",
            "country": "Romania",
            "country_code": "ROU",
            "abbreviation": "BOJ"
          }
        },
        {
          "rank": 426,
          "movement": 0,
          "points": 153,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:52388",
            "name": "Hesse, Amandine",
            "country": "France",
            "country_code": "FRA",
            "abbreviation": "HES"
          }
        },
        {
          "rank": 427,
          "movement": -4,
          "points": 153,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:827440",
            "name": "Fedorova, Aglaya",
            "country": "Neutral",
            "abbreviation": "FED"
          }
        },
        {
          "rank": 428,
          "movement": -1,
          "points": 152,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:812476",
            "name": "Zaytseva, Ksenia",
            "country": "Neutral",
            "abbreviation": "ZAY"
          }
        },
        {
          "rank": 429,
          "movement": -22,
          "points": 151,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:196664",
            "name": "Shalimova, Ekaterina",
            "country": "Neutral",
            "abbreviation": "SHA"
          }
        },
        {
          "rank": 430,
          "movement": 0,
          "points": 151,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:119664",
            "name": "Smith, Alicia",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "SMI"
          }
        },
        {
          "rank": 431,
          "movement": 0,
          "points": 150,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:221510",
            "name": "Chiesa, Enola",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "CHI"
          }
        },
        {
          "rank": 432,
          "movement": 0,
          "points": 150,
          "competitions_played": 30,
          "competitor": {
            "id": "sr:competitor:341238",
            "name": "Boehner, Laura",
            "country": "Germany",
            "country_code": "DEU",
            "abbreviation": "BOE"
          }
        },
        {
          "rank": 433,
          "movement": 0,
          "points": 149,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:1027517",
            "name": "Ebeling Koning, Loes",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "EBE"
          }
        },
        {
          "rank": 434,
          "movement": 11,
          "points": 149,
          "competitions_played": 25,
          "competitor": {
            "id": "sr:competitor:171026",
            "name": "Tsygourova, Katerina",
            "country": "Switzerland",
            "country_code": "CHE",
            "abbreviation": "TSY"
          }
        },
        {
          "rank": 435,
          "movement": -1,
          "points": 148,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:102191",
            "name": "Aksu, Ayla",
            "country": "Turkiye",
            "country_code": "TUR",
            "abbreviation": "AKS"
          }
        },
        {
          "rank": 436,
          "movement": 0,
          "points": 148,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:766176",
            "name": "Di Girolami, Tilwith",
            "country": "Belgium",
            "country_code": "BEL",
            "abbreviation": "DI"
          }
        },
        {
          "rank": 437,
          "movement": 0,
          "points": 147,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:133080",
            "name": "Hinojosa Gomez, Jessica",
            "country": "Mexico",
            "country_code": "MEX",
            "abbreviation": "HIN"
          }
        },
        {
          "rank": 438,
          "movement": 0,
          "points": 146,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:58423",
            "name": "Stevanovic, Natalija",
            "country": "Serbia",
            "country_code": "SRB",
            "abbreviation": "STE"
          }
        },
        {
          "rank": 439,
          "movement": 0,
          "points": 146,
          "competitions_played": 25,
          "competitor": {
            "id": "sr:competitor:185412",
            "name": "Labrana, Fernanda",
            "country": "Chile",
            "country_code": "CHL",
            "abbreviation": "LAB"
          }
        },
        {
          "rank": 440,
          "movement": -5,
          "points": 146,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:677411",
            "name": "Barrera Aguirre, Isabella",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "BAR"
          }
        },
        {
          "rank": 441,
          "movement": -1,
          "points": 145,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:522258",
            "name": "Ricci, Beatrice",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "RIC"
          }
        },
        {
          "rank": 442,
          "movement": -1,
          "points": 145,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:831284",
            "name": "Kuramochi, Miho",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "KUR"
          }
        },
        {
          "rank": 443,
          "movement": -1,
          "points": 145,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:831262",
            "name": "Yamalapalli, Sahaja",
            "country": "India",
            "country_code": "IND",
            "abbreviation": "YAM"
          }
        },
        {
          "rank": 444,
          "movement": 3,
          "points": 145,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:371556",
            "name": "Jeong, Boyoung",
            "country": "Republic of Korea",
            "country_code": "KOR",
            "abbreviation": "JEO"
          }
        },
        {
          "rank": 445,
          "movement": -2,
          "points": 144,
          "competitions_played": 6,
          "competitor": {
            "id": "sr:competitor:517296",
            "name": "Falei, Aliona",
            "country": "Neutral",
            "abbreviation": "FAL"
          }
        },
        {
          "rank": 446,
          "movement": -2,
          "points": 144,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:849553",
            "name": "Yao, Xinxin",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "YAO"
          }
        },
        {
          "rank": 447,
          "movement": 25,
          "points": 143,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:858867",
            "name": "Pace, Francesca",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "PAC"
          }
        },
        {
          "rank": 448,
          "movement": 63,
          "points": 142,
          "competitions_played": 4,
          "competitor": {
            "id": "sr:competitor:100341",
            "name": "Bolkvadze, Mariam",
            "country": "Georgia",
            "country_code": "GEO",
            "abbreviation": "BOL"
          }
        },
        {
          "rank": 449,
          "movement": -3,
          "points": 142,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:341196",
            "name": "Back, Dayeon",
            "country": "Republic of Korea",
            "country_code": "KOR",
            "abbreviation": "BAC"
          }
        },
        {
          "rank": 450,
          "movement": -2,
          "points": 141,
          "competitions_played": 3,
          "competitor": {
            "id": "sr:competitor:499484",
            "name": "Montgomery, Robin",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "MON"
          }
        },
        {
          "rank": 451,
          "movement": -2,
          "points": 140,
          "competitions_played": 7,
          "competitor": {
            "id": "sr:competitor:329535",
            "name": "Tauson, Clara",
            "country": "Denmark",
            "country_code": "DNK",
            "abbreviation": "TAU"
          }
        },
        {
          "rank": 452,
          "movement": -2,
          "points": 140,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:655811",
            "name": "Avdeeva, Julia",
            "country": "Neutral",
            "abbreviation": "AVD"
          }
        },
        {
          "rank": 453,
          "movement": -2,
          "points": 140,
          "competitions_played": 16,
          "competitor": {
            "id": "sr:competitor:192138",
            "name": "Corley, Paris",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "COR"
          }
        },
        {
          "rank": 454,
          "movement": -2,
          "points": 140,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:511932",
            "name": "Kovaleva, Anastasia",
            "country": "Neutral",
            "abbreviation": "KOV"
          }
        },
        {
          "rank": 455,
          "movement": -2,
          "points": 140,
          "competitions_played": 19,
          "competitor": {
            "id": "sr:competitor:522848",
            "name": "Rocchetti, Sofia",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "ROC"
          }
        },
        {
          "rank": 456,
          "movement": -2,
          "points": 139,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:906635",
            "name": "Shubladze, Alexandra",
            "country": "Neutral",
            "abbreviation": "SHU"
          }
        },
        {
          "rank": 457,
          "movement": -2,
          "points": 138,
          "competitions_played": 9,
          "competitor": {
            "id": "sr:competitor:880229",
            "name": "Cayetano, Eryn",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "CAY"
          }
        },
        {
          "rank": 458,
          "movement": -1,
          "points": 138,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:96981",
            "name": "Xun, Fang Ying",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "XUN"
          }
        },
        {
          "rank": 459,
          "movement": -1,
          "points": 137,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:310982",
            "name": "Naklo, Thasaporn",
            "country": "Thailand",
            "country_code": "THA",
            "abbreviation": "NAK"
          }
        },
        {
          "rank": 460,
          "movement": -1,
          "points": 137,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:360054",
            "name": "Allen, Kolie",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "ALL"
          }
        },
        {
          "rank": 461,
          "movement": -1,
          "points": 137,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:111149",
            "name": "Samir, Sandra",
            "country": "Egypt",
            "country_code": "EGY",
            "abbreviation": "SAM"
          }
        },
        {
          "rank": 462,
          "movement": -1,
          "points": 136,
          "competitions_played": 3,
          "competitor": {
            "id": "sr:competitor:595220",
            "name": "Stakusic, Marina",
            "country": "Canada",
            "country_code": "CAN",
            "abbreviation": "STA"
          }
        },
        {
          "rank": 463,
          "movement": -1,
          "points": 136,
          "competitions_played": 9,
          "competitor": {
            "id": "sr:competitor:431743",
            "name": "Okutoyi, Angella",
            "country": "Kenya",
            "country_code": "KEN",
            "abbreviation": "OKU"
          }
        },
        {
          "rank": 464,
          "movement": -1,
          "points": 136,
          "competitions_played": 18,
          "competitor": {
            "id": "sr:competitor:476218",
            "name": "Kawaguchi, Natsumi",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "KAW"
          }
        },
        {
          "rank": 465,
          "movement": -1,
          "points": 135,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:739667",
            "name": "Pedone, Giorgia",
            "country": "Italy",
            "country_code": "ITA",
            "abbreviation": "PED"
          }
        },
        {
          "rank": 466,
          "movement": -1,
          "points": 135,
          "competitions_played": 22,
          "competitor": {
            "id": "sr:competitor:569009",
            "name": "Ccuno, Romina",
            "country": "Peru",
            "country_code": "PER",
            "abbreviation": "CCU"
          }
        },
        {
          "rank": 467,
          "movement": -1,
          "points": 135,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:804342",
            "name": "Stoiber, Ranah Akua",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "STO"
          }
        },
        {
          "rank": 468,
          "movement": 0,
          "points": 133,
          "competitions_played": 6,
          "competitor": {
            "id": "sr:competitor:51477",
            "name": "Mitu, Andreea",
            "country": "Romania",
            "country_code": "ROU",
            "abbreviation": "MIT"
          }
        },
        {
          "rank": 469,
          "movement": -2,
          "points": 133,
          "competitions_played": 8,
          "competitor": {
            "id": "sr:competitor:342788",
            "name": "Curmi, Francesca",
            "country": "Malta",
            "country_code": "MLT",
            "abbreviation": "CUR"
          }
        },
        {
          "rank": 470,
          "movement": -1,
          "points": 133,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:265743",
            "name": "Burdina, Evgeniya",
            "country": "Neutral",
            "abbreviation": "BUR"
          }
        },
        {
          "rank": 471,
          "movement": -1,
          "points": 132,
          "competitions_played": 17,
          "competitor": {
            "id": "sr:competitor:315623",
            "name": "Wang, Jiaqi",
            "country": "China",
            "country_code": "CHN",
            "abbreviation": "WAN"
          }
        },
        {
          "rank": 472,
          "movement": -63,
          "points": 132,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:190870",
            "name": "Collins, Ali",
            "country": "Great Britain",
            "country_code": "GBR",
            "abbreviation": "COL"
          }
        },
        {
          "rank": 473,
          "movement": -2,
          "points": 132,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:340365",
            "name": "Milovanovic, Elena",
            "country": "Serbia",
            "country_code": "SRB",
            "abbreviation": "MIL"
          }
        },
        {
          "rank": 474,
          "movement": -1,
          "points": 131,
          "competitions_played": 2,
          "competitor": {
            "id": "sr:competitor:71034",
            "name": "Sramkova, Rebecca",
            "country": "Slovakia",
            "country_code": "SVK",
            "abbreviation": "SRA"
          }
        },
        {
          "rank": 475,
          "movement": -1,
          "points": 131,
          "competitions_played": 2,
          "competitor": {
            "id": "sr:competitor:19704",
            "name": "Martic, Petra",
            "country": "Croatia",
            "country_code": "HRV",
            "abbreviation": "MAR"
          }
        },
        {
          "rank": 476,
          "movement": -1,
          "points": 131,
          "competitions_played": 7,
          "competitor": {
            "id": "sr:competitor:46661",
            "name": "Gamiz, Andrea",
            "country": "Venezuela",
            "country_code": "VEN",
            "abbreviation": "GAM"
          }
        },
        {
          "rank": 477,
          "movement": -1,
          "points": 131,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:264863",
            "name": "Novak, Kristina",
            "country": "Slovenia",
            "country_code": "SVN",
            "abbreviation": "NOV"
          }
        },
        {
          "rank": 478,
          "movement": -1,
          "points": 131,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:915371",
            "name": "van Den Broek, Isis Louise",
            "country": "Netherlands",
            "country_code": "NLD",
            "abbreviation": "VAN"
          }
        },
        {
          "rank": 479,
          "movement": -1,
          "points": 130,
          "competitions_played": 11,
          "competitor": {
            "id": "sr:competitor:784280",
            "name": "Prozorova, Tatiana",
            "country": "Neutral",
            "abbreviation": "PRO"
          }
        },
        {
          "rank": 480,
          "movement": -1,
          "points": 130,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:494296",
            "name": "Steur, Joelle Lilly Sophie",
            "country": "Germany",
            "country_code": "DEU",
            "abbreviation": "STE"
          }
        },
        {
          "rank": 481,
          "movement": -25,
          "points": 130,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:583869",
            "name": "Pavlou, Dimitra",
            "country": "Greece",
            "country_code": "GRC",
            "abbreviation": "PAV"
          }
        },
        {
          "rank": 482,
          "movement": -2,
          "points": 129,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:827398",
            "name": "Stankovic, Anja",
            "country": "Serbia",
            "country_code": "SRB",
            "abbreviation": "STA"
          }
        },
        {
          "rank": 483,
          "movement": -1,
          "points": 128,
          "competitions_played": 4,
          "competitor": {
            "id": "sr:competitor:343160",
            "name": "Volynets, Katie",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "VOL"
          }
        },
        {
          "rank": 484,
          "movement": -1,
          "points": 128,
          "competitions_played": 9,
          "competitor": {
            "id": "sr:competitor:686597",
            "name": "Pavlova, Kira",
            "country": "Neutral",
            "abbreviation": "PAV"
          }
        },
        {
          "rank": 485,
          "movement": -1,
          "points": 128,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:833330",
            "name": "Grechkina, Anastasia",
            "country": "Neutral",
            "abbreviation": "GRE"
          }
        },
        {
          "rank": 486,
          "movement": -1,
          "points": 127,
          "competitions_played": 21,
          "competitor": {
            "id": "sr:competitor:447759",
            "name": "Katsumi, Nanari",
            "country": "Japan",
            "country_code": "JPN",
            "abbreviation": "KAT"
          }
        },
        {
          "rank": 487,
          "movement": -1,
          "points": 126,
          "competitions_played": 4,
          "competitor": {
            "id": "sr:competitor:39425",
            "name": "Savinykh, Valeria",
            "country": "Neutral",
            "abbreviation": "SAV"
          }
        },
        {
          "rank": 488,
          "movement": -1,
          "points": 126,
          "competitions_played": 26,
          "competitor": {
            "id": "sr:competitor:69964",
            "name": "Estable, Julieta Lara",
            "country": "Argentina",
            "country_code": "ARG",
            "abbreviation": "EST"
          }
        },
        {
          "rank": 489,
          "movement": -1,
          "points": 126,
          "competitions_played": 9,
          "competitor": {
            "id": "sr:competitor:18350",
            "name": "Voracova, Renata",
            "country": "Czechia",
            "country_code": "CZE",
            "abbreviation": "VOR"
          }
        },
        {
          "rank": 490,
          "movement": -1,
          "points": 126,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:840734",
            "name": "Walker, Brandy",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "WAL"
          }
        },
        {
          "rank": 491,
          "movement": -1,
          "points": 126,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:18731",
            "name": "Paszek, Tamira",
            "country": "Austria",
            "country_code": "AUT",
            "abbreviation": "PAS"
          }
        },
        {
          "rank": 492,
          "movement": -1,
          "points": 125,
          "competitions_played": 10,
          "competitor": {
            "id": "sr:competitor:378226",
            "name": "Crawley, Fiona",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "CRA"
          }
        },
        {
          "rank": 493,
          "movement": -1,
          "points": 125,
          "competitions_played": 12,
          "competitor": {
            "id": "sr:competitor:262701",
            "name": "Hodzic, Mina",
            "country": "Germany",
            "country_code": "DEU",
            "abbreviation": "HOD"
          }
        },
        {
          "rank": 494,
          "movement": -1,
          "points": 124,
          "competitions_played": 5,
          "competitor": {
            "id": "sr:competitor:60276",
            "name": "Podoroska, Nadia",
            "country": "Argentina",
            "country_code": "ARG",
            "abbreviation": "POD"
          }
        },
        {
          "rank": 495,
          "movement": -1,
          "points": 124,
          "competitions_played": 4,
          "competitor": {
            "id": "sr:competitor:32862",
            "name": "Diatchenko, Vitalia",
            "country": "Neutral",
            "abbreviation": "DIA"
          }
        },
        {
          "rank": 496,
          "movement": -1,
          "points": 124,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:230108",
            "name": "McGiffin, Tenika",
            "country": "Australia",
            "country_code": "AUS",
            "abbreviation": "MCG"
          }
        },
        {
          "rank": 497,
          "movement": -1,
          "points": 124,
          "competitions_played": 15,
          "competitor": {
            "id": "sr:competitor:720627",
            "name": "Senic, Natalija",
            "country": "Serbia",
            "country_code": "SRB",
            "abbreviation": "SEN"
          }
        },
        {
          "rank": 498,
          "movement": -1,
          "points": 123,
          "competitions_played": 5,
          "competitor": {
            "id": "sr:competitor:90814",
            "name": "Teichmann, Jil",
            "country": "Switzerland",
            "country_code": "CHE",
            "abbreviation": "TEI"
          }
        },
        {
          "rank": 499,
          "movement": -1,
          "points": 123,
          "competitions_played": 8,
          "competitor": {
            "id": "sr:competitor:723099",
            "name": "Ewald, Weronika",
            "country": "Poland",
            "country_code": "POL",
            "abbreviation": "EWA"
          }
        },
        {
          "rank": 500,
          "movement": -1,
          "points": 123,
          "competitions_played": 13,
          "competitor": {
            "id": "sr:competitor:675193",
            "name": "Costoulas, Sofia",
            "country": "Belgium",
            "country_code": "BEL",
            "abbreviation": "COS"
          }
        },
        {
          "rank": 501,
          "movement": -1,
          "points": 123,
          "competitions_played": 14,
          "competitor": {
            "id": "sr:competitor:418447",
            "name": "Sieg, Madison",
            "country": "USA",
            "country_code": "USA",
            "abbreviation": "SIE"
          }
        }
  ]

# %%
connection = mysql.connector.connect(
    host="localhost",       
    user="root",            
    password="",          
    database="doubles"    
)
mycursor = connection.cursor()

# %%
insert_query = ("""
    INSERT INTO doubles.competitor(competitor_id, name,country,country_code,abbreviation) 
    VALUES (%s, %s,%s,%s,%s) 
    ON DUPLICATE KEY UPDATE 
           
    name = VALUES(name),
    country=VALUES(country),
    country_code=VALUES(country_code),
    abbreviation=VALUES(abbreviation)
                """
)

# %%
for item in data:
    competitor = item.get("competitor")  # Get 'competitor' safely

    if not competitor:  # Skip if 'competitor' is missing or None
        continue  

    values = (
        competitor.get("id"), 
        competitor.get("name"),
        competitor.get("country"),
        competitor.get("country_code"),
        competitor.get("abbreviation")
    )
    
    mycursor.execute(insert_query, values)

# %%
connection.commit()
mycursor.close()
connection.close()

print("Competitor data successfully inserted into MySQL.")
# Out:
# Competitor data successfully inserted into MySQL.

# %%
mycursor.execute("ALTER TABLE doubles.competitor MODIFY country_code VARCHAR(10) NULL")
